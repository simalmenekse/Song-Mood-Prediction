# %%
#import of general packages
import warnings
import pickle
import pandas as pd
import numpy as np

# import sklearn functionalities
import sklearn
from sklearn import pipeline
from sklearn import model_selection
from sklearn import svm
from sklearn import metrics
from sklearn import preprocessing
from sklearn import linear_model
from sklearn import neighbors
from sklearn import naive_bayes
from sklearn import ensemble
from sklearn import neural_network
from sklearn import decomposition

# %%
# toggle warnings
warnings.filterwarnings('ignore')
# warnings.filterwarnings('default')

# %%
basic_features = pd.read_csv("../data/features.csv")
basic_features
# Out:
#                                 title            artist       tempo  \
# 0                           Pray Slow      Chase Shakur   80.749512
# 1                              Reborn     Colin Stetson  143.554688
# 2                                Roll      Ethan Fields  112.347147
# 3                                  12              Home   89.102909
# 4                           Byzantium              Home  135.999178
# 5                  Drawing The Blinds              Home   89.102909
# 6                          Head First              Home  135.999178
# 7                               Intro              Home   99.384014
# 8                           Resonance              Home  112.347147
# 9                Gravitational Forces       ITG Studios  135.999178
# 10              Sunshine Girl (Pt. 2)             Jakob   75.999540
# 11                      All Your Love       Jakob Ogawa   86.132812
# 12  You Might Be Sleeping (w. Clairo)       Jakob Ogawa   92.285156
# 13                      In This Shirt   Jamie McDermott  161.499023
# 14                Looking Out For You         Joy Again   99.384014
# 15                   Feel Like A Fool        Kali Uchis  107.666016
# 16                          Telepatia        Kali Uchis   83.354335
# 17      i want war (BUT I NEED PEACE)        Kali Uchis   89.102909
# 18                         Half Sleep              Lamp   95.703125
# 19                     From The Start            Laufey  107.666016
# 20      Don’t Stop Til You Get Enough   Michael Jackson  117.453835
# 21                     Leave Me Alone   Michael Jackson  123.046875
# 22                      Rock With You   Michael Jackson  112.347147
# 23                        Speed Demon   Micheal Jackson   99.384014
# 24                             Gekiha            Naruto  117.453835
# 25                             Decode          Paramore  161.499023
# 26                       Parking Lots             Plums  151.999081
# 27                          Kill Bill               SZA   89.102909
# 28                   Sao Paulo Sunset              Saib  117.453835
# 29           Annie Chases a Butterfly  Silk Skin Lovers  129.199219
# 30                         Bahia Baby         SpongeBob  107.666016
# 31                       Epic Tragedy         SpongeBob  143.554688
# 32                             F Song    Strawberry Guy  172.265625
# 33                    Birds Dont Sing           TV Girl  107.666016
# 34                          Blue Hair           TV Girl  135.999178
# 35                Blue Hair (sped up)           TV Girl  107.666016
# 36          Cigarettes out the Window           TV Girl  117.453835
# 37                        Lovers Rock           TV Girl  103.359375
# 38                       Natalie Wood           TV Girl  135.999178
# 39                        Not Allowed           TV Girl  103.359375
# 40                  The White Stripes    The Glitch Mob  117.453835
# 41                         Telephones         VACATIONS  151.999081
# 42                             Actors         Vacations  151.999081
# 43                        On Your Own         Vacations  143.554688
# 44                             Steady         Vacations  151.999081
# 45                              Kyrie  Yoshihisa Hirano  129.199219
# 46                       Fly Out West          Yot Club  172.265625
# 47           i hope she loves me back         boy pablo  172.265625
# 48                          sleepless            odyzon  172.265625
#
#     chroma_number  zero_crossing_rate  energy_entropy  spectral_centroid  \
# 0       -0.000407            0.022947        3.149726           0.100529
# 1       -0.009726            0.040007        3.212871           0.111733
# 2        0.013494            0.031987        3.123152           0.125037
# 3        0.040640            0.010608        3.085242           0.072542
# 4        0.010142            0.038684        3.150813           0.119300
# 5       -0.010804            0.041825        3.138335           0.123426
# 6       -0.009489            0.035582        3.096984           0.100086
# 7       -0.044664            0.023140        3.178904           0.075927
# 8       -0.023123            0.019254        3.137959           0.078118
# 9       -0.004197            0.017798        3.040058           0.093822
# 10      -0.015666            0.018546        3.094522           0.098135
# 11      -0.012113            0.032611        3.093993           0.098540
# 12      -0.003454            0.026851        3.163705           0.090017
# 13       0.001478            0.043009        3.223715           0.101307
# 14       0.009438            0.045941        3.109662           0.112675
# 15      -0.009557            0.055727        3.166845           0.141314
# 16       0.021440            0.039607        3.146406           0.125280
# 17      -0.046769            0.044189        3.124969           0.139181
# 18       0.010640            0.020326        3.196977           0.074314
# 19      -0.013684            0.028754        3.177046           0.104290
# 20       0.030695            0.086442        3.037726           0.171270
# 21       0.023046            0.077827        3.131467           0.163452
# 22       0.007377            0.084850        3.113855           0.173464
# 23      -0.005174            0.065211        3.011945           0.158451
# 24      -0.003424            0.074282        3.100833           0.156072
# 25      -0.011964            0.063210        3.211475           0.134503
# 26       0.018692            0.070227        3.224220           0.142785
# 27      -0.012984            0.034008        3.188648           0.103874
# 28       0.011937            0.047851        3.061098           0.137236
# 29       0.014116            0.028824        3.185343           0.097304
# 30       0.006064            0.028205        3.124335           0.095121
# 31      -0.014927            0.046403        3.253214           0.091566
# 32      -0.015071            0.040241        3.184216           0.097753
# 33       0.014082            0.058893        3.171878           0.134071
# 34       0.021436            0.050455        3.158151           0.132657
# 35      -0.005827            0.042319        3.146260           0.117554
# 36      -0.028108            0.060634        3.166267           0.149587
# 37      -0.011972            0.057898        3.115839           0.141333
# 38      -0.009788            0.061780        3.117142           0.148518
# 39      -0.017938            0.035049        3.158445           0.098305
# 40       0.006673            0.030427        3.089109           0.106161
# 41       0.004744            0.031469        3.186215           0.111889
# 42       0.025785            0.057919        3.199993           0.123717
# 43       0.018562            0.047829        3.184205           0.114829
# 44      -0.002420            0.051168        3.178251           0.116822
# 45      -0.008105            0.031372        3.225559           0.078180
# 46       0.010771            0.048201        3.189875           0.107196
# 47      -0.014764            0.044763        3.211649           0.115725
# 48       0.011239            0.012999        3.050920           0.073393
#
#     primary  secondary
# 0         4          5
# 1         1          4
# 2         2          3
# 3         4          5
# 4         1          3
# 5         2          4
# 6         1          2
# 7         2          4
# 8         2          5
# 9         1          6
# 10        2          4
# 11        4          5
# 12        2          4
# 13        1          6
# 14        2          3
# 15        2          5
# 16        2          4
# 17        4          5
# 18        2          4
# 19        2          6
# 20        3          6
# 21        3          6
# 22        2          4
# 23        3          6
# 24        1          3
# 25        1          3
# 26        3          6
# 27        2          4
# 28        2          6
# 29        3          4
# 30        2          4
# 31        1          6
# 32        4          5
# 33        2          3
# 34        2          3
# 35        3          6
# 36        2          3
# 37        2          3
# 38        3          6
# 39        3          4
# 40        1          6
# 41        4          5
# 42        3          6
# 43        3          4
# 44        2          3
# 45        1          6
# 46        3          6
# 47        2          3
# 48        4          5

# %%
basic_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               49 non-null     object
#  1   artist              49 non-null     object
#  2   tempo               49 non-null     float64
#  3   chroma_number       49 non-null     float64
#  4   zero_crossing_rate  49 non-null     float64
#  5   energy_entropy      49 non-null     float64
#  6   spectral_centroid   49 non-null     float64
#  7   primary             49 non-null     int64
#  8   secondary           49 non-null     int64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 3.6+ KB

# %%
basic_features.describe()
# Out:
#             tempo  chroma_number  zero_crossing_rate  energy_entropy  \
# count   49.000000      49.000000           49.000000       49.000000
# mean   121.434893      -0.000686            0.043023        3.146735
# std     27.168457       0.017680            0.018292        0.054654
# min     75.999540      -0.046769            0.010608        3.011945
# 25%     99.384014      -0.011972            0.030427        3.113855
# 50%    117.453835      -0.003424            0.041825        3.150813
# 75%    143.554688       0.011239            0.055727        3.185343
# max    172.265625       0.040640            0.086442        3.253214
#
#        spectral_centroid    primary  secondary
# count          49.000000  49.000000  49.000000
# mean            0.115885   2.306122   4.530612
# std             0.026370   0.961858   1.209374
# min             0.072542   1.000000   2.000000
# 25%             0.098135   2.000000   4.000000
# 50%             0.112675   2.000000   4.000000
# 75%             0.134503   3.000000   6.000000
# max             0.173464   4.000000   6.000000

# %%
eng_features = pd.read_csv("../data/engineered_features.csv")
eng_features
# Out:
#                                 title            artist       tempo  \
# 0                           Pray Slow      Chase Shakur   80.749512
# 1                              Reborn     Colin Stetson  143.554688
# 2                                Roll      Ethan Fields  112.347147
# 3                                  12              Home   89.102909
# 4                           Byzantium              Home  135.999178
# 5                  Drawing The Blinds              Home   89.102909
# 6                          Head First              Home  135.999178
# 7                               Intro              Home   99.384014
# 8                           Resonance              Home  112.347147
# 9                Gravitational Forces       ITG Studios  135.999178
# 10              Sunshine Girl (Pt. 2)             Jakob   75.999540
# 11                      All Your Love       Jakob Ogawa   86.132812
# 12  You Might Be Sleeping (w. Clairo)       Jakob Ogawa   92.285156
# 13                      In This Shirt   Jamie McDermott  161.499023
# 14                Looking Out For You         Joy Again   99.384014
# 15                   Feel Like A Fool        Kali Uchis  107.666016
# 16                          Telepatia        Kali Uchis   83.354335
# 17      i want war (BUT I NEED PEACE)        Kali Uchis   89.102909
# 18                         Half Sleep              Lamp   95.703125
# 19                     From The Start            Laufey  107.666016
# 20      Don’t Stop Til You Get Enough   Michael Jackson  117.453835
# 21                     Leave Me Alone   Michael Jackson  123.046875
# 22                      Rock With You   Michael Jackson  112.347147
# 23                        Speed Demon   Micheal Jackson   99.384014
# 24                             Gekiha            Naruto  117.453835
# 25                             Decode          Paramore  161.499023
# 26                       Parking Lots             Plums  151.999081
# 27                          Kill Bill               SZA   89.102909
# 28                   Sao Paulo Sunset              Saib  117.453835
# 29           Annie Chases a Butterfly  Silk Skin Lovers  129.199219
# 30                         Bahia Baby         SpongeBob  107.666016
# 31                       Epic Tragedy         SpongeBob  143.554688
# 32                             F Song    Strawberry Guy  172.265625
# 33                    Birds Dont Sing           TV Girl  107.666016
# 34                          Blue Hair           TV Girl  135.999178
# 35                Blue Hair (sped up)           TV Girl  107.666016
# 36          Cigarettes out the Window           TV Girl  117.453835
# 37                        Lovers Rock           TV Girl  103.359375
# 38                       Natalie Wood           TV Girl  135.999178
# 39                        Not Allowed           TV Girl  103.359375
# 40                  The White Stripes    The Glitch Mob  117.453835
# 45      -0.008105  0.031372  0.006792     0.024577             3.225559
# 46       0.010771  0.048201  0.013682     0.033920             3.189875
# 47      -0.014764  0.044763  0.013199     0.041024             3.211649
# 48       0.011239  0.012999  0.002638     0.049038             3.050920
#
#     spectral_centroid_mean  spectral_spread_mean  ...  delta energy_std  \
# 0                 0.100529              0.163562  ...          0.059472
# 1                 0.111733              0.161664  ...          0.007091
# 2                 0.125037              0.177614  ...          0.048894
# 3                 0.072542              0.147221  ...          0.012299
# 4                 0.119300              0.156493  ...          0.037722
# 5                 0.123426              0.169007  ...          0.031561
# 6                 0.100086              0.146246  ...          0.042732
# 7                 0.075927              0.141992  ...          0.010922
# 8                 0.078118              0.145261  ...          0.061921
# 9                 0.093822              0.165921  ...          0.020140
# 10                0.098135              0.173398  ...          0.040459
# 11                0.098540              0.154144  ...          0.072326
# 12                0.090017              0.152228  ...          0.056132
# 13                0.101307              0.146256  ...          0.010183
# 14                0.112675              0.152273  ...          0.048726
# 15                0.141314              0.174628  ...          0.054925
# 16                0.125280              0.172543  ...          0.041625
# 17                0.139181              0.189971  ...          0.017018
# 18                0.074314              0.148099  ...          0.013158
# 19                0.104290              0.166358  ...          0.047981
# 20                0.171270              0.177588  ...          0.039447
# 21                0.163452              0.180366  ...          0.041832
# 22                0.173464              0.187984  ...          0.040259
# 23                0.158451              0.178278  ...          0.016110
# 24                0.156072              0.163859  ...          0.027212
# 25                0.134503              0.159684  ...          0.024046
# 26                0.142785              0.162099  ...          0.025957
# 27                0.103874              0.152463  ...          0.067396
# 28                0.137236              0.179073  ...          0.038734
# 29                0.097304              0.155532  ...          0.016898
# 30                0.095121              0.152155  ...          0.013406
# 31                0.091566              0.130186  ...          0.022693
# 32                0.097753              0.139942  ...          0.010051
# 33                0.134071              0.162049  ...          0.043308
# 34                0.132657              0.165406  ...          0.033282
# 35                0.117554              0.157898  ...          0.030290
# 36                0.149587              0.189905  ...          0.037512
# 37                0.141333              0.170432  ...          0.040364
# 38                0.148518              0.174867  ...          0.037850
# 39                0.098305              0.149085  ...          0.042360
# 40                0.106161              0.160338  ...          0.040270
# 41                0.111889              0.163678  ...          0.027118
# 42                0.123717              0.154148  ...          0.057287
# 43                0.114829              0.155505  ...          0.049050
# 44                0.116822              0.150533  ...          0.019678
# 45                0.078180              0.131330  ...          0.008056
# 46                0.107196              0.142070  ...          0.014661
# 47                0.115725              0.156888  ...          0.017101
# 48                0.073393              0.155044  ...          0.007330
#
#     delta mfcc_1_std  delta mfcc_3_std  delta mfcc_13_std  \
# 0           1.005960          0.403339           0.224575
# 1           0.362496          0.262763           0.193761
# 2           1.808481          0.578886           0.274285
# 3           1.372463          0.434742           0.180317
# 4           1.357249          0.484079           0.219621
# 5           1.096700          0.408545           0.244143
# 6           1.180623          0.503945           0.218634
# 7           0.860971          0.299406           0.226869
# 8           0.932585          0.486303           0.201469
# 9           1.098646          0.287604           0.184712
# 10          1.405963          0.375335           0.204849
# 11          1.231564          0.522135           0.247734
# 12          0.852563          0.443761           0.207401
# 13          0.388202          0.248273           0.191291
# 14          1.381732          0.434503           0.215782
# 3                  0.019458                   0.045563        4          5
# 4                  0.013648                   0.043370        1          3
# 5                  0.010030                   0.029254        2          4
# 6                  0.009717                   0.043519        1          2
# 7                  0.008715                   0.054390        2          4
# 8                  0.012369                   0.057298        2          5
# 9                  0.007262                   0.045157        1          6
# 10                 0.013057                   0.043618        2          4
# 11                 0.016616                   0.041627        4          5
# 12                 0.008787                   0.040730        2          4
# 13                 0.002756                   0.033167        1          6
# 14                 0.005729                   0.030969        2          3
# 15                 0.004950                   0.023935        2          5
# 16                 0.010692                   0.032150        2          4
# 17                 0.005221                   0.031857        4          5
# 18                 0.010059                   0.057260        2          4
# 19                 0.012685                   0.038141        2          6
# 20                 0.007212                   0.028700        3          6
# 21                 0.004396                   0.029813        3          6
# 22                 0.006744                   0.034602        2          4
# 23                 0.008136                   0.033115        3          6
# 24                 0.004613                   0.019570        1          3
# 25                 0.003926                   0.023668        1          3
# 26                 0.003541                   0.025344        3          6
# 27                 0.010436                   0.036243        2          4
# 28                 0.007520                   0.030125        2          6
# 29                 0.006602                   0.043784        3          4
# 30                 0.009878                   0.041355        2          4
# 31                 0.005568                   0.043690        1          6
# 32                 0.003787                   0.037699        4          5
# 33                 0.004814                   0.028093        2          3
# 34                 0.004875                   0.026996        2          3
# 35                 0.005376                   0.032460        3          6
# 36                 0.006366                   0.034208        2          3
# 37                 0.003487                   0.029839        2          3
# 38                 0.006187                   0.026784        3          6
# 39                 0.005869                   0.035305        3          4
# 40                 0.006660                   0.033953        1          6
# 41                 0.007709                   0.040821        4          5
# 42                 0.005376                   0.028423        3          6
# 43                 0.005348                   0.034463        3          4
# 44                 0.009519                   0.035519        2          3
# 45                 0.009863                   0.045756        1          6
# 46                 0.005220                   0.033686        3          6
# 47                 0.006177                   0.029793        2          3
# 48                 0.007674                   0.053438        4          5
#
# [49 rows x 32 columns]

# %%
eng_features.describe()
# Out:
#             tempo  chroma_number   zcr_mean    zcr_std  energy_mean  \
# count   49.000000      49.000000  49.000000  49.000000    49.000000
# mean   121.434893      -0.000686   0.043023   0.017544     0.056638
# std     27.168457       0.017680   0.018292   0.009463     0.024400
# min     75.999540      -0.046769   0.010608   0.002638     0.014864
# 25%     99.384014      -0.011972   0.030427   0.010523     0.036364
# 50%    117.453835      -0.003424   0.041825   0.016668     0.050990
# 75%    143.554688       0.011239   0.055727   0.021894     0.072566
# max    172.265625       0.040640   0.086442   0.048060     0.113506
#
#        energy_entropy_mean  spectral_centroid_mean  spectral_spread_mean  \
# count            49.000000               49.000000             49.000000
# mean              3.146735                0.115885              0.160475
# std               0.054654                0.026370              0.014202
# min               3.011945                0.072542              0.130186
# 25%               3.113855                0.098135              0.152155
# 50%               3.150813                0.112675              0.159684
# 75%               3.185343                0.134503              0.170432
# max               3.253214                0.173464              0.189971
#
#        spectral_entropy_mean  mfcc_2_mean  ...  delta energy_std  \
# count              49.000000    49.000000  ...         49.000000
# mean                0.322082     2.115118  ...          0.033160
# std                 0.209016     0.682326  ...          0.017314
# min                 0.029695     0.734009  ...          0.007091
# 25%                 0.185399     1.586838  ...          0.017018
# 50%                 0.306158     2.001489  ...          0.037512
# 75%                 0.394479     2.491694  ...          0.042732
# max                 0.834119     3.845136  ...          0.072326
#
#        delta mfcc_1_std  delta mfcc_3_std  delta mfcc_13_std  \
# count         49.000000         49.000000          49.000000
# mean           1.024243          0.374655           0.216127
# std            0.370794          0.082473           0.020553
# min            0.362496          0.231463           0.170736
# 25%            0.739314          0.312207           0.204849
# 50%            0.997201          0.375335           0.217310
# 75%            1.268226          0.429048           0.228304
# max            2.061046          0.578886           0.274285
#
#        delta spectral_centroid_std  delta spectral_entropy_std  \
# count                    49.000000                   49.000000
# mean                      0.032996                    0.196408
# std                       0.008784                    0.117939
# min                       0.020575                    0.019294
# 25%                       0.025824                    0.117144
# 50%                       0.031785                    0.175943
# 75%                       0.037351                    0.253565
# max                       0.054876                    0.586013
#
#        delta spectral_flux_std  delta spectral_spread_std    primary  \
# count                49.000000                  49.000000  49.000000
# mean                  0.007854                   0.036618   2.306122
# std                   0.003716                   0.008785   0.961858
# min                   0.002462                   0.019570   1.000000
# 25%                   0.005221                   0.029839   2.000000
# 50%                   0.006744                   0.034602   2.000000
# 75%                   0.009878                   0.043370   3.000000
# max                   0.019458                   0.057298   4.000000
#
#        secondary
# count  49.000000
# mean    4.530612
# std     1.209374
# min     2.000000
# 25%     4.000000
# 50%     4.000000
# 75%     6.000000
# max     6.000000
#
# [8 rows x 30 columns]

# %%
eng_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   title                        49 non-null     object
#  1   artist                       49 non-null     object
#  2   tempo                        49 non-null     float64
#  3   chroma_number                49 non-null     float64
#  4   zcr_mean                     49 non-null     float64
#  5   zcr_std                      49 non-null     float64
#  6   energy_mean                  49 non-null     float64
#  7   energy_entropy_mean          49 non-null     float64
#  8   spectral_centroid_mean       49 non-null     float64
#  9   spectral_spread_mean         49 non-null     float64
#  10  spectral_entropy_mean        49 non-null     float64
#  11  mfcc_2_mean                  49 non-null     float64
#  12  mfcc_5_mean                  49 non-null     float64
#  13  mfcc_6_mean                  49 non-null     float64
#  14  spectral_centroid_std        49 non-null     float64
#  15  spectral_entropy_std         49 non-null     float64
#  16  spectral_spread_std          49 non-null     float64
#  17  chroma_7_std                 49 non-null     float64
#  18  delta chroma_2_std           49 non-null     float64
#  19  delta chroma_3_std           49 non-null     float64
#  20  delta chroma_9_std           49 non-null     float64
#  21  delta chroma_std_std         49 non-null     float64
#  22  delta energy_std             49 non-null     float64
#  23  delta mfcc_1_std             49 non-null     float64
#  24  delta mfcc_3_std             49 non-null     float64
#  25  delta mfcc_13_std            49 non-null     float64
#  26  delta spectral_centroid_std  49 non-null     float64
#  27  delta spectral_entropy_std   49 non-null     float64
#  28  delta spectral_flux_std      49 non-null     float64
#  29  delta spectral_spread_std    49 non-null     float64
#  30  primary                      49 non-null     int64
#  31  secondary                    49 non-null     int64
# dtypes: float64(28), int64(2), object(2)
# memory usage: 12.4+ KB

# %%
nn_features = pd.read_csv("../data/nn_features.csv")
nn_features
# Out:
#     zcr_mean  energy_mean  energy_entropy_mean  spectral_centroid_mean  \
# 0   0.022947     0.106520             3.149726                0.100529
# 1   0.040007     0.038373             3.212871                0.111733
# 4                                  Home - Byzantium
# 5                         Home - Drawing The Blinds
# 6                                 Home - Head First
# 7                                      Home - Intro
# 8                                  Home - Resonance
# 9                ITG Studios - Gravitational Forces
# 10                    Jakob - Sunshine Girl (Pt. 2)
# 11                      Jakob Ogawa - All Your Love
# 12  Jakob Ogawa - You Might Be Sleeping (w. Clairo)
# 13                  Jamie McDermott - In This Shirt
# 14                  Joy Again - Looking Out For You
# 15                    Kali Uchis - Feel Like A Fool
# 16                           Kali Uchis - Telepatia
# 17       Kali Uchis - i want war (BUT I NEED PEACE)
# 18                                Lamp - Half Sleep
# 19                          Laufey - From The Start
# 20  Michael Jackson - Don’t Stop Til You Get Enough
# 21                 Michael Jackson - Leave Me Alone
# 22                  Michael Jackson - Rock With You
# 23                    Micheal Jackson - Speed Demon
# 24                                  Naruto - Gekiha
# 25                                Paramore - Decode
# 26                             Plums - Parking Lots
# 27                                  SZA - Kill Bill
# 28                          Saib - Sao Paulo Sunset
# 29      Silk Skin Lovers - Annie Chases a Butterfly
# 30                           SpongeBob - Bahia Baby
# 31                         SpongeBob - Epic Tragedy
# 32                          Strawberry Guy - F Song
# 33                        TV Girl - Birds Dont Sing
# 34                              TV Girl - Blue Hair
# 35                    TV Girl - Blue Hair (sped up)
# 36              TV Girl - Cigarettes out the Window
# 37                            TV Girl - Lovers Rock
# 38                           TV Girl - Natalie Wood
# 39                            TV Girl - Not Allowed
# 40               The Glitch Mob - The White Stripes
# 41                           VACATIONS - Telephones
# 42                               Vacations - Actors
# 43                          Vacations - On Your Own
# 44                               Vacations - Steady
# 45                         Yoshihisa Hirano - Kyrie
# 46                          Yot Club - Fly Out West
# 47             boy pablo - i hope she loves me back
# 48                               odyzon - sleepless
#
# [49 rows x 137 columns]

# %%
nn_features.describe()
# Out:
#         zcr_mean  energy_mean  energy_entropy_mean  spectral_centroid_mean  \
# count  21.000000    21.000000            21.000000               21.000000
# mean    0.046549     0.060716             3.161490                0.121464
# std     0.012340     0.021438             0.034897                0.018020
# min     0.022947     0.020750             3.093993                0.097304
# 25%     0.039607     0.048256             3.146260                0.107196
# 50%     0.045941     0.067622             3.166267                0.117554
# 75%     0.057898     0.074389             3.185343                0.139181
# max     0.070227     0.106520             3.224220                0.149587
#
#        spectral_spread_mean  spectral_entropy_mean  spectral_flux_mean  \
# count             21.000000              21.000000           21.000000
# mean               0.162220               0.352243            0.006425
# std                0.013190               0.147934            0.002213
# min                0.139942               0.141208            0.003504
# 25%                0.154148               0.219004            0.005270
# 50%                0.162049               0.327231            0.005869
# 75%                0.170432               0.399440            0.006438
# max                0.189971               0.722574            0.013278
#
#        spectral_rolloff_mean  mfcc_1_mean  mfcc_2_mean  ...  \
# count              21.000000    21.000000    21.000000  ...
# mean                0.065550   -23.769684     1.996493  ...
# std                 0.020637     1.007854     0.533075  ...
# min                 0.032800   -25.989062     0.734009  ...
# 25%                 0.050301   -24.575265     1.697492  ...
# 50%                 0.064533   -23.623992     2.001489  ...
# 75%                 0.076326   -23.108155     2.288192  ...
# max                 0.114637   -22.211989     3.071246  ...
#
#        delta chroma_4_std  delta chroma_5_std  delta chroma_6_std  \
# count           21.000000           21.000000           21.000000
# mean             0.011527            0.018185            0.010357
# std              0.006104            0.005752            0.005013
# min              0.003754            0.009023            0.002807
# 25%              0.008081            0.014283            0.007232
# 50%              0.009766            0.018374            0.009444
# 75%              0.013287            0.023413            0.013117
# max              0.028070            0.029955            0.024118
#
#        delta chroma_7_std  delta chroma_8_std  delta chroma_9_std  \
# count           21.000000           21.000000           21.000000
# mean             0.044373            0.004075            0.007614
# std              0.015855            0.002227            0.003778
# min              0.020522            0.001404            0.002524
# 25%              0.029457            0.003021            0.004792
# 50%              0.041420            0.003455            0.007096
# 75%              0.057613            0.004485            0.009966
# max              0.074259            0.010377            0.017183
#
#        delta chroma_10_std  delta chroma_11_std  delta chroma_12_std  \
# count            21.000000            21.000000            21.000000
# mean              0.016108             0.029523             0.006087
# std               0.005856             0.011011             0.002629
# min               0.007167             0.015177             0.002738
# 25%               0.010974             0.021067             0.004130
# 50%               0.015739             0.025054             0.005552
# 75%               0.020879             0.037004             0.007807
# max               0.025936             0.055650             0.012433
#
#        delta chroma_std_std
# count             21.000000
# mean               0.013054
# std                0.003385
# min                0.007701
# 25%                0.010510
# 50%                0.012883
# 75%                0.015168
# max                0.019393
#
# [8 rows x 136 columns]

# %%
nn_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Columns: 137 entries, zcr_mean to song
# dtypes: float64(136), object(1)
# memory usage: 52.6+ KB

# %%
# add mood to the neural network dataframe
combined_nn = pd.concat([basic_features, nn_features], axis = 1)
combined_nn['song_check'] = combined_nn['artist'] + ' - ' + combined_nn['title']

# print a message to check if merge was successful
if combined_nn['song'].equals(combined_nn['song_check']):
    print ("Neural network features match.")
    combined_nn = combined_nn.drop(columns = ['song', 'song_check'])
else:
    print ("Neural network features DO NOT match.")
# Out:
# Neural network features match.

# %%
eng_features.columns
# Out:
# Index(['title', 'artist', 'tempo', 'chroma_number', 'zcr_mean', 'zcr_std',
#        'energy_mean', 'energy_entropy_mean', 'spectral_centroid_mean',
#        'spectral_spread_mean', 'spectral_entropy_mean', 'mfcc_2_mean',
#        'mfcc_5_mean', 'mfcc_6_mean', 'spectral_centroid_std',
#        'spectral_entropy_std', 'spectral_spread_std', 'chroma_7_std',
#        'delta chroma_2_std', 'delta chroma_3_std', 'delta chroma_9_std',
#        'delta chroma_std_std', 'delta energy_std', 'delta mfcc_1_std',
#        'delta mfcc_3_std', 'delta mfcc_13_std', 'delta spectral_centroid_std',
#        'delta spectral_entropy_std', 'delta spectral_flux_std',
#        'delta spectral_spread_std', 'primary', 'secondary'],
#       dtype='object')

# %%
# function to separate features and labels
def build_xy(features, feature_type):
    if feature_type == "basic":
        # basic features only include the five listed
        columns_to_exclude = ['title', 'artist', 'primary', 'secondary']
        x = features.drop(columns=columns_to_exclude)
    elif feature_type == "eng":
        columns_to_exclude = ['title', 'artist', 'primary', 'secondary']
        x = features.drop(columns=columns_to_exclude)
    elif feature_type == "neural_net":
        # 9 is the index of zcr_mean, the first neural network feature
        x = features.iloc[:, 9:]
    else:
        print ("Invalid feature type.")
        return (None, None)
    
    y = features[['primary', 'secondary']]
    # generate a combined label containing both primary and secondary moods
    y['combined'] = y['primary'].astype(str) + y['secondary'].astype(str)
    return (x, y)

# %%
# function to generate scoring based on primary and secondary moods
def evaluate_mood(y_true, y_predict):
    true_list = y_true.tolist()
    score_values = []
    for index, value in enumerate(y_predict):
        true_moods = true_list[index]
        if str(value) == true_moods[0]:
            # give full credit for getting the primary mood
            score_values.append(1)
        elif str(value) in list(true_moods):
            # give partial credit for getting the secondary mood instead
            score_values.append(0.5)
        else:
            score_values.append(0)
    return pd.Series(score_values)

# %%
# Support Vector Machine with basic features
x, y = build_xy(basic_features, "basic")
svm_model = svm.SVC()
scaler = preprocessing.MinMaxScaler()
pipe = pipeline.Pipeline(steps = [('scaler', scaler), ('svc', svm_model)])
param_grid = {
    'svc__kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
    'svc__decision_function_shape': ['ovr', 'ovo'],
    'svc__C': [0.25, 0.5, 0.75, 1, 3, 5, 10, 25, 50],
    'svc__gamma': [0.0001, 0.001, 0.01, 0.1, 1, 5, 10],
}
model = model_selection.GridSearchCV(pipe, param_grid, cv = 5)
accuracies = model_selection.cross_val_score(model, x, y['primary'], cv = 5)
print("Average accuracy:", np.mean(accuracies))
# Out:
# Average accuracy: 0.40888888888888886

# %%
# Support Vector Machine with engineered features
x, y = build_xy(eng_features, "eng")
svm_model = svm.SVC()
scaler = preprocessing.MinMaxScaler()
pipe = pipeline.Pipeline(steps = [('scaler', scaler), ('svc', svm_model)])
param_grid = {
    'svc__kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
    'svc__decision_function_shape': ['ovr', 'ovo'],
    'svc__C': [0.25, 0.5, 0.75, 1, 3, 5, 10, 25, 50],
    'svc__gamma': [0.0001, 0.001, 0.01, 0.1, 1, 5, 10],
}
model = model_selection.GridSearchCV(pipe, param_grid, cv = 5)
accuracies = model_selection.cross_val_score(model, x, y['primary'], cv = 5)
print("Average accuracy:", np.mean(accuracies))
# Out:
# Average accuracy: 0.44666666666666666

# %%
# Support Vector Machine with PCA transformed engineered features
x, y = build_xy(eng_features, "eng")
svm_model = svm.SVC()
scaler = preprocessing.MinMaxScaler()
pca = decomposition.PCA(n_components = 0.95, svd_solver = "full")
pipe = pipeline.Pipeline(steps = [('scaler', scaler), ('pca', pca), ('svc', svm_model)])
param_grid = {
    'svc__kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
    'svc__decision_function_shape': ['ovr', 'ovo'],
    'svc__C': [0.25, 0.5, 0.75, 1, 3, 5, 10, 25, 50],
    'svc__gamma': [0.0001, 0.001, 0.01, 0.1, 1, 5, 10],
}
model = model_selection.GridSearchCV(pipe, param_grid, cv = 5)
accuracies = model_selection.cross_val_score(model, x, y['primary'], cv = 5)
print("Average accuracy:", np.mean(accuracies))
# Out:
# Average accuracy: 0.5311111111111112

# %%
# final basic SVM model
x, y = build_xy(basic_features, "basic")
svm_model = svm.SVC()
scaler = preprocessing.MinMaxScaler()
pipe = pipeline.Pipeline(steps = [('scaler', scaler), ('svc', svm_model)])
param_grid = {
    'svc__kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
    'svc__decision_function_shape': ['ovr', 'ovo'],
    'svc__C': [0.25, 0.5, 0.75, 1, 3, 5, 10, 25, 50],
    'svc__gamma': [0.0001, 0.001, 0.01, 0.1, 1, 5, 10],
}
model = model_selection.GridSearchCV(pipe, param_grid, cv = 5)
model.fit(x, y['primary'])
print ("***SVM Best Parameters***")
print (model.best_params_)
# Out:
# ***SVM Best Parameters***
# {'svc__C': 0.5, 'svc__decision_function_shape': 'ovr', 'svc__gamma': 1, 'svc__kernel': 'poly'}

# %%
# final engineered SVM model
x, y = build_xy(eng_features, "eng")
svm_model = svm.SVC()
scaler = preprocessing.MinMaxScaler()
pipe = pipeline.Pipeline(steps = [('scaler', scaler), ('svc', svm_model)])
param_grid = {
    'svc__kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
    'svc__decision_function_shape': ['ovr', 'ovo'],
    'svc__C': [0.25, 0.5, 0.75, 1, 3, 5, 10, 25, 50],
    'svc__gamma': [0.0001, 0.001, 0.01, 0.1, 1, 5, 10],
}
model = model_selection.GridSearchCV(pipe, param_grid, cv = 5)
model.fit(x, y['primary'])
print ("***SVM Best Parameters***")
print (model.best_params_)
# Out:
# ***SVM Best Parameters***
# {'svc__C': 0.75, 'svc__decision_function_shape': 'ovr', 'svc__gamma': 0.0001, 'svc__kernel': 'linear'}

# %%
# final transformed and engineered SVM model
x, y = build_xy(eng_features, "eng")
svm_model = svm.SVC()
scaler = preprocessing.MinMaxScaler()
pca = decomposition.PCA(n_components = 0.95, svd_solver = "full")
pipe = pipeline.Pipeline(steps = [('scaler', scaler), ('pca', pca), ('svc', svm_model)])
param_grid = {
    'svc__kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
    'svc__decision_function_shape': ['ovr', 'ovo'],
    'svc__C': [0.25, 0.5, 0.75, 1, 3, 5, 10, 25, 50],
    'svc__gamma': [0.0001, 0.001, 0.01, 0.1, 1, 5, 10],
}
model = model_selection.GridSearchCV(pipe, param_grid, cv = 5)
model.fit(x, y['primary'])
print ("***SVM Best Parameters***")
print (model.best_params_)
# Out:
# ***SVM Best Parameters***
# {'svc__C': 1, 'svc__decision_function_shape': 'ovr', 'svc__gamma': 1, 'svc__kernel': 'poly'}

# %%
# Logistic Regression with basic features
x, y = build_xy(basic_features, "basic")
lr_model = linear_model.LogisticRegression()
scaler = preprocessing.MinMaxScaler()
pipe = pipeline.Pipeline(steps = [('scaler', scaler), ('log_reg', lr_model)])
param_grid = {
    'log_reg__penalty': ['l2', 'elasticnet', 'none'],
    'log_reg__solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'],
    'log_reg__C': [0.25, 0.5, 0.75, 1, 3, 5, 10, 25, 50]
}
model = model_selection.GridSearchCV(pipe, param_grid, cv = 5)
accuracies = model_selection.cross_val_score(model, x, y['primary'], cv = 5)
print("Average accuracy:", np.mean(accuracies))
# Out:
# Average accuracy: 0.40666666666666673

# %%
# Logistic Regression with engineered features
x, y = build_xy(eng_features, "eng")
lr_model = linear_model.LogisticRegression()
scaler = preprocessing.MinMaxScaler()
pipe = pipeline.Pipeline(steps = [('scaler', scaler), ('log_reg', lr_model)])
param_grid = {
    'log_reg__penalty': ['l2', 'elasticnet', 'none'],
    'log_reg__solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'],
    'log_reg__C': [0.25, 0.5, 0.75, 1, 3, 5, 10, 25, 50]
}
model = model_selection.GridSearchCV(pipe, param_grid, cv = 5)
accuracies = model_selection.cross_val_score(model, x, y['primary'], cv = 5)
print("Average accuracy:", np.mean(accuracies))
# Out:
# Average accuracy: 0.42444444444444446

# %%
# Logistic Regression with PCA transformed engineered features
x, y = build_xy(eng_features, "eng")
lr_model = linear_model.LogisticRegression()
scaler = preprocessing.MinMaxScaler()
pca = decomposition.PCA(n_components = 0.95, svd_solver = "full")
pipe = pipeline.Pipeline(steps = [('scaler', scaler), ('pca', pca), ('log_reg', lr_model)])
param_grid = {
    'log_reg__penalty': ['l2', 'elasticnet', 'none'],
    'log_reg__solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'],
    'log_reg__C': [0.25, 0.5, 0.75, 1, 3, 5, 10, 25, 50]
}
model = model_selection.GridSearchCV(pipe, param_grid, cv = 5)
accuracies = model_selection.cross_val_score(model, x, y['primary'], cv = 5)
print("Average accuracy:", np.mean(accuracies))
# Out:
# Average accuracy: 0.4444444444444445

# %%
# final basic LR model
x, y = build_xy(basic_features, "basic")
lr_model = linear_model.LogisticRegression()
scaler = preprocessing.MinMaxScaler()
pipe = pipeline.Pipeline(steps = [('scaler', scaler), ('log_reg', lr_model)])
param_grid = {
    'log_reg__penalty': ['l2', 'elasticnet', 'none'],
    'log_reg__solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'],
    'log_reg__C': [0.25, 0.5, 0.75, 1, 3, 5, 10, 25, 50]
}
model = model_selection.GridSearchCV(pipe, param_grid, cv = 5)
model.fit(x, y['primary'])
print ("***LR Best Parameters***")
print (model.best_params_)
# Out:
# ***LR Best Parameters***
# {'log_reg__C': 0.25, 'log_reg__penalty': 'l2', 'log_reg__solver': 'newton-cg'}

# %%
# Logistic Regression with PCA transformed engineered features
x, y = build_xy(eng_features, "eng")
lr_model = linear_model.LogisticRegression()
scaler = preprocessing.MinMaxScaler()
pca = decomposition.PCA(n_components = 0.95, svd_solver = "full")
pipe = pipeline.Pipeline(steps = [('scaler', scaler), ('pca', pca), ('log_reg', lr_model)])
param_grid = {
    'log_reg__penalty': ['l2', 'elasticnet', 'none'],
    'log_reg__solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'],
    'log_reg__C': [0.25, 0.5, 0.75, 1, 3, 5, 10, 25, 50]
}
model = model_selection.GridSearchCV(pipe, param_grid, cv = 5)
accuracies = model_selection.cross_val_score(model, x, y['primary'], cv = 5)
print("Average accuracy:", np.mean(accuracies))
# Out:
# Average accuracy: 0.4444444444444445

# %%
# final basic LR model
x, y = build_xy(basic_features, "basic")
lr_model = linear_model.LogisticRegression()
scaler = preprocessing.MinMaxScaler()
pipe = pipeline.Pipeline(steps = [('scaler', scaler), ('log_reg', lr_model)])
param_grid = {
    'log_reg__penalty': ['l2', 'elasticnet', 'none'],
    'log_reg__solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'],
    'log_reg__C': [0.25, 0.5, 0.75, 1, 3, 5, 10, 25, 50]
}
model = model_selection.GridSearchCV(pipe, param_grid, cv = 5)
model.fit(x, y['primary'])
print ("***LR Best Parameters***")
print (model.best_params_)
# Out:
# ***LR Best Parameters***
# {'log_reg__C': 0.25, 'log_reg__penalty': 'l2', 'log_reg__solver': 'newton-cg'}

# %%
# final engineered LR model
x, y = build_xy(eng_features, "eng")
lr_model = linear_model.LogisticRegression()
scaler = preprocessing.MinMaxScaler()
pipe = pipeline.Pipeline(steps = [('scaler', scaler), ('log_reg', lr_model)])
param_grid = {
    'log_reg__penalty': ['l2', 'elasticnet', 'none'],
    'log_reg__solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'],
    'log_reg__C': [0.25, 0.5, 0.75, 1, 3, 5, 10, 25, 50]
}
model = model_selection.GridSearchCV(pipe, param_grid, cv = 5)
model.fit(x, y['primary'])
print ("***LR Best Parameters***")
print (model.best_params_)
# Out:
# ***LR Best Parameters***
# {'log_reg__C': 10, 'log_reg__penalty': 'l2', 'log_reg__solver': 'newton-cg'}

# %%
# final transformed and engineered LR model
x, y = build_xy(eng_features, "eng")
lr_model = linear_model.LogisticRegression()
scaler = preprocessing.MinMaxScaler()
pca = decomposition.PCA(n_components = 0.95, svd_solver = "full")
pipe = pipeline.Pipeline(steps = [('scaler', scaler), ('pca', pca), ('log_reg', lr_model)])
param_grid = {
    'log_reg__penalty': ['l2', 'elasticnet', 'none'],
    'log_reg__solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'],
    'log_reg__C': [0.25, 0.5, 0.75, 1, 3, 5, 10, 25, 50]
}
model = model_selection.GridSearchCV(pipe, param_grid, cv = 5)
model.fit(x, y['primary'])
print ("***LR Best Parameters***")
print (model.best_params_)
# Out:
# ***LR Best Parameters***
# {'log_reg__C': 0.5, 'log_reg__penalty': 'l2', 'log_reg__solver': 'newton-cg'}

# %%
# K Nearest Neighbor with basic features
x, y = build_xy(basic_features, "basic")
knn_model = neighbors.KNeighborsClassifier()
scaler = preprocessing.MinMaxScaler()
pipe = pipeline.Pipeline(steps = [('scaler', scaler), ('knn', knn_model)])
param_grid = {
    'knn__n_neighbors': [1, 3, 5, 7, 9, 11, 13, 15],
    'knn__weights': ['uniform', 'distance'],
    'knn__metric': ['euclidean', 'manhattan', 'chebyshev', 'minkowski', 'wminkowski', 'seuclidean', 'mahalanobis'],
}
model = model_selection.GridSearchCV(pipe, param_grid, cv = 5)
accuracies = model_selection.cross_val_score(model, x, y['primary'], cv = 5)
print("Average accuracy:", np.mean(accuracies))
# Out:
# Average accuracy: 0.4866666666666667

# %%
# K Nearest Neighbor with engineered features
x, y = build_xy(eng_features, "eng")
knn_model = neighbors.KNeighborsClassifier()
scaler = preprocessing.MinMaxScaler()
pipe = pipeline.Pipeline(steps = [('scaler', scaler), ('knn', knn_model)])
param_grid = {
    'knn__n_neighbors': [1, 3, 5, 7, 9, 11, 13, 15],
    'knn__weights': ['uniform', 'distance'],
    'knn__metric': ['euclidean', 'manhattan', 'chebyshev', 'minkowski', 'wminkowski', 'seuclidean', 'mahalanobis'],
}
model = model_selection.GridSearchCV(pipe, param_grid, cv = 5)
accuracies = model_selection.cross_val_score(model, x, y['primary'], cv = 5)
print("Average accuracy:", np.mean(accuracies))
# Out:
# Average accuracy: 0.43111111111111117

# %%
# K Nearest Neighbor with PCA transformed engineered features
x, y = build_xy(eng_features, "eng")
knn_model = neighbors.KNeighborsClassifier()
scaler = preprocessing.MinMaxScaler()
pca = decomposition.PCA(n_components = 0.95, svd_solver = "full")
pipe = pipeline.Pipeline(steps = [('scaler', scaler), ('pca', pca), ('knn', knn_model)])
param_grid = {
    'knn__n_neighbors': [1, 3, 5, 7, 9, 11, 13, 15],
    'knn__weights': ['uniform', 'distance'],
    'knn__metric': ['euclidean', 'manhattan', 'chebyshev', 'minkowski', 'wminkowski', 'seuclidean', 'mahalanobis'],
}
model = model_selection.GridSearchCV(pipe, param_grid, cv = 5)
accuracies = model_selection.cross_val_score(model, x, y['primary'], cv = 5)
print("Average accuracy:", np.mean(accuracies))
# Out:
# Average accuracy: 0.45111111111111113

# %%
# final basic KNN model
x, y = build_xy(basic_features, "basic")
knn_model = neighbors.KNeighborsClassifier()
scaler = preprocessing.MinMaxScaler()
pipe = pipeline.Pipeline(steps = [('scaler', scaler), ('knn', knn_model)])
param_grid = {
    'knn__n_neighbors': [1, 3, 5, 7, 9, 11, 13, 15],
    'knn__weights': ['uniform', 'distance'],
    'knn__metric': ['euclidean', 'manhattan', 'chebyshev', 'minkowski', 'wminkowski', 'seuclidean', 'mahalanobis'],
}
model = model_selection.GridSearchCV(pipe, param_grid, cv = 5)
model.fit(x, y['primary'])
print ("***KNN Best Parameters***")
print (model.best_params_)
# Out:
# ***KNN Best Parameters***
# {'knn__metric': 'manhattan', 'knn__n_neighbors': 11, 'knn__weights': 'distance'}

# %%
# final engineered KNN model
x, y = build_xy(eng_features, "eng")
knn_model = neighbors.KNeighborsClassifier()
scaler = preprocessing.MinMaxScaler()
pipe = pipeline.Pipeline(steps = [('scaler', scaler), ('knn', knn_model)])
param_grid = {
    'knn__n_neighbors': [1, 3, 5, 7, 9, 11, 13, 15],
    'knn__weights': ['uniform', 'distance'],
    'knn__metric': ['euclidean', 'manhattan', 'chebyshev', 'minkowski', 'wminkowski', 'seuclidean', 'mahalanobis'],
}
model = model_selection.GridSearchCV(pipe, param_grid, cv = 5)
model.fit(x, y['primary'])
print ("***KNN Best Parameters***")
print (model.best_params_)
# Out:
# ***KNN Best Parameters***
# {'knn__metric': 'euclidean', 'knn__n_neighbors': 7, 'knn__weights': 'uniform'}

# %%
# final transformed and engineered KNN model
x, y = build_xy(eng_features, "eng")
knn_model = neighbors.KNeighborsClassifier()
scaler = preprocessing.MinMaxScaler()
pca = decomposition.PCA(n_components = 0.95, svd_solver = "full")
pipe = pipeline.Pipeline(steps = [('scaler', scaler), ('pca', pca), ('knn', knn_model)])
param_grid = {
    'knn__n_neighbors': [1, 3, 5, 7, 9, 11, 13, 15],
    'knn__weights': ['uniform', 'distance'],
    'knn__metric': ['euclidean', 'manhattan', 'chebyshev', 'minkowski', 'wminkowski', 'seuclidean', 'mahalanobis'],
}
model = model_selection.GridSearchCV(pipe, param_grid, cv = 5)
model.fit(x, y['primary'])
print ("***KNN Best Parameters***")
print (model.best_params_)
# Out:
# ***KNN Best Parameters***
# {'knn__metric': 'chebyshev', 'knn__n_neighbors': 3, 'knn__weights': 'uniform'}

# %%
# Gaussian Naive Bayes with basic features
x, y = build_xy(basic_features, "basic")
nb_model = naive_bayes.GaussianNB()
param_grid = {
    'var_smoothing': [0.000000001, 0.00000001, 0.0000001, 0.000001],
}
model = model_selection.GridSearchCV(nb_model, param_grid, cv = 5)
accuracies = model_selection.cross_val_score(model, x, y['primary'], cv = 5)
print("Average accuracy:", np.mean(accuracies))
# Out:
# Average accuracy: 0.48888888888888893

# %%
# Gaussian Naive Bayes with engineered features
x, y = build_xy(eng_features, "eng")
nb_model = naive_bayes.GaussianNB()
param_grid = {
    'var_smoothing': [0.000000001, 0.00000001, 0.0000001, 0.000001],
}
model = model_selection.GridSearchCV(nb_model, param_grid, cv = 5)
accuracies = model_selection.cross_val_score(model, x, y['primary'], cv = 5)
print("Average accuracy:", np.mean(accuracies))
# Out:
# Average accuracy: 0.40444444444444444

# %%
# Gaussian Naive Bayes with PCA transformed engineered features
x, y = build_xy(eng_features, "eng")
nb_model = naive_bayes.GaussianNB()
scaler = preprocessing.MinMaxScaler()
pca = decomposition.PCA(n_components = 0.95, svd_solver = "full")
pipe = pipeline.Pipeline(steps = [('scaler', scaler), ('pca', pca), ('gnb', nb_model)])
param_grid = {
    'gnb__var_smoothing': [0.000000001, 0.00000001, 0.0000001, 0.000001],
}
model = model_selection.GridSearchCV(pipe, param_grid, cv = 5)
accuracies = model_selection.cross_val_score(model, x, y['primary'], cv = 5)
print("Average accuracy:", np.mean(accuracies))
# Out:
# Average accuracy: 0.30666666666666664

# %%
# final basic GNB model
x, y = build_xy(basic_features, "basic")
nb_model = naive_bayes.GaussianNB()
param_grid = {
    'var_smoothing': [0.000000001, 0.00000001, 0.0000001, 0.000001],
}
model = model_selection.GridSearchCV(nb_model, param_grid, cv = 5)
model.fit(x, y['primary'])
print ("***GNB Best Parameters***")
print (model.best_params_)
# Out:
# ***GNB Best Parameters***
# {'var_smoothing': 1e-07}

# %%
# final engineered GNB model
x, y = build_xy(eng_features, "eng")
nb_model = naive_bayes.GaussianNB()
param_grid = {
    'var_smoothing': [0.000000001, 0.00000001, 0.0000001, 0.000001],
}
model = model_selection.GridSearchCV(nb_model, param_grid, cv = 5)
model.fit(x, y['primary'])
print ("***GNB Best Parameters***")
print (model.best_params_)
# Out:
# ***GNB Best Parameters***
# {'var_smoothing': 1e-06}

# %%
# final transformed and engineered GNB model
x, y = build_xy(eng_features, "eng")
nb_model = naive_bayes.GaussianNB()
scaler = preprocessing.MinMaxScaler()
pca = decomposition.PCA(n_components = 0.95, svd_solver = "full")
pipe = pipeline.Pipeline(steps = [('scaler', scaler), ('pca', pca), ('gnb', nb_model)])
param_grid = {
    'gnb__var_smoothing': [0.000000001, 0.00000001, 0.0000001, 0.000001],
}
model = model_selection.GridSearchCV(pipe, param_grid, cv = 5)
model.fit(x, y['primary'])
print ("***GNB Best Parameters***")
print (model.best_params_)
# Out:
# ***GNB Best Parameters***
# {'gnb__var_smoothing': 1e-09}

# %%
# Random Forest with basic features
x, y = build_xy(basic_features, "basic")
rf_model = ensemble.RandomForestClassifier()
param_grid = {
    'max_depth': [5, 10, 15, 20, 25, 50, 75, None],
    'min_samples_leaf': [1, 2, 5, 7, 10, 12, 15],
    'max_features': ["sqrt", "log2"]
}
model = model_selection.GridSearchCV(rf_model, param_grid, cv = 5)
accuracies = model_selection.cross_val_score(model, x, y['primary'], cv = 5)
print("Average accuracy:", np.mean(accuracies))
# Out:
# Average accuracy: 0.40444444444444444

# %%
# Random Forest with engineered features
x, y = build_xy(eng_features, "eng")
rf_model = ensemble.RandomForestClassifier()
param_grid = {
    'max_depth': [5, 10, 15, 20, 25, 50, 75, None],
    'min_samples_leaf': [1, 2, 5, 7, 10, 12, 15],
    'max_features': ["sqrt", "log2"]
}
model = model_selection.GridSearchCV(rf_model, param_grid, cv = 5)
accuracies = model_selection.cross_val_score(model, x, y['primary'], cv = 5)
print("Average accuracy:", np.mean(accuracies))
# Out:
# Average accuracy: 0.4688888888888888

# %%
# Random Forest with PCA transformed engineered features
x, y = build_xy(eng_features, "eng")
rf_model = ensemble.RandomForestClassifier()
scaler = preprocessing.MinMaxScaler()
pca = decomposition.PCA(n_components = 0.95, svd_solver = "full")
pipe = pipeline.Pipeline(steps = [('scaler', scaler), ('pca', pca), ('forest', rf_model)])
param_grid = {
    'forest__max_depth': [5, 10, 15, 20, 25, 50, 75, None],
    'forest__min_samples_leaf': [1, 2, 5, 7, 10, 12, 15],
    'forest__max_features': ["sqrt", "log2"]
}
model = model_selection.GridSearchCV(pipe, param_grid, cv = 5)
accuracies = model_selection.cross_val_score(model, x, y['primary'], cv = 5)
print("Average accuracy:", np.mean(accuracies))
# Out:
# Average accuracy: 0.3244444444444444

# %%
# final basic RF model
x, y = build_xy(basic_features, "basic")
rf_model = ensemble.RandomForestClassifier()
param_grid = {
    'max_depth': [5, 10, 15, 20, 25, 50, 75, None],
    'min_samples_leaf': [1, 2, 5, 7, 10, 12, 15],
    'max_features': ["sqrt", "log2"]
}
model = model_selection.GridSearchCV(rf_model, param_grid, cv = 5)
model.fit(x, y['primary'])
print ("***RF Best Parameters***")
print (model.best_params_)
# Out:
# ***RF Best Parameters***
# {'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 2}

# %%
# final engineered RF model
x, y = build_xy(eng_features, "eng")
rf_model = ensemble.RandomForestClassifier()
param_grid = {
    'max_depth': [5, 10, 15, 20, 25, 50, 75, None],
    'min_samples_leaf': [1, 2, 5, 7, 10, 12, 15],
    'max_features': ["sqrt", "log2"]
}
model = model_selection.GridSearchCV(rf_model, param_grid, cv = 5)
model.fit(x, y['primary'])
print ("***RF Best Parameters***")
print (model.best_params_)
# Out:
# ***RF Best Parameters***
# {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5}

# %%
# final transformed and engineered RF model
x, y = build_xy(eng_features, "eng")
rf_model = ensemble.RandomForestClassifier()
scaler = preprocessing.MinMaxScaler()
pca = decomposition.PCA(n_components = 0.95, svd_solver = "full")
pipe = pipeline.Pipeline(steps = [('scaler', scaler), ('pca', pca), ('forest', rf_model)])
param_grid = {
    'forest__max_depth': [5, 10, 15, 20, 25, 50, 75, None],
    'forest__min_samples_leaf': [1, 2, 5, 7, 10, 12, 15],
    'forest__max_features': ["sqrt", "log2"]
}
model = model_selection.GridSearchCV(pipe, param_grid, cv = 5)
model.fit(x, y['primary'])
print ("***RF Best Parameters***")
print (model.best_params_)
# Out:
# ***RF Best Parameters***
# {'forest__max_depth': None, 'forest__max_features': 'log2', 'forest__min_samples_leaf': 7}

# %%
# Multi-Layer Perceptron with neural network features
x, y = build_xy(combined_nn, "neural_net")
mlp_model = neural_network.MLPClassifier()
scaler = preprocessing.MinMaxScaler()
pipe = pipeline.Pipeline(steps = [('scaler', scaler), ('mlp', mlp_model)])
param_grid = {
    'mlp__hidden_layer_sizes': [(10,), (20,), (30,), (40,), (50,), (60,)],
    'mlp__activation': ['logistic', 'tanh', 'relu', 'identity'],
    'mlp__solver': ['lbfgs', 'sgd', 'adam'],
    'mlp__alpha': [0.00001, 0.0001, 0.001, 0.01, 0.1],
}
model = model_selection.GridSearchCV(pipe, param_grid, cv = 5)
accuracies = model_selection.cross_val_score(model, x, y['primary'], cv = 5)
print("Average accuracy:", np.mean(accuracies))
# Out:
# Average accuracy: 0.5311111111111112

# %%
# export the final MLP model
x, y = build_xy(combined_nn, "neural_net")
mlp_model = neural_network.MLPClassifier()
scaler = preprocessing.MinMaxScaler()
pipe = pipeline.Pipeline(steps = [('scaler', scaler), ('mlp', mlp_model)])
param_grid = {
    'mlp__hidden_layer_sizes': [(10,), (20,), (30,), (40,), (50,), (60,)],
    'mlp__activation': ['logistic', 'tanh', 'relu', 'identity'],
    'mlp__solver': ['lbfgs', 'sgd', 'adam'],
    'mlp__alpha': [0.00001, 0.0001, 0.001, 0.01, 0.1],
}
model = model_selection.GridSearchCV(pipe, param_grid, cv = 5)
model.fit(x, y['primary'])

# use pickle to save the model
final_mlp_model = model
pickle.dump(final_mlp_model, open('mood_mlp_model.sav', 'wb'))

# %%
# export the stacking model with best parameters from each individual model
# use engineered features, which performed the best on all individual models when compared to basic features
x, y = build_xy(eng_features, "eng")

le = preprocessing.LabelEncoder()
y_encoded = le.fit_transform(y['primary'])

svc_pipe = pipeline.make_pipeline(preprocessing.MinMaxScaler(), 
                                  svm.SVC(C = 5, decision_function_shape = 'ovr', gamma = 0.1, kernel = 'sigmoid'))
lr_pipe = pipeline.make_pipeline(preprocessing.MinMaxScaler(),
                                 decomposition.PCA(n_components = 0.95, svd_solver = "full"),
                                 linear_model.LogisticRegression(C = 0.25, penalty = 'l2', solver = 'liblinear'))
knn_pipe = pipeline.make_pipeline(preprocessing.MinMaxScaler(),
                                  decomposition.PCA(n_components = 0.95, svd_solver = "full"),
                                  neighbors.KNeighborsClassifier(metric = 'chebyshev', n_neighbors = 9, weights = 'distance'))
gnb_pipe = pipeline.make_pipeline(preprocessing.MinMaxScaler(),
                                  decomposition.PCA(n_components = 0.95, svd_solver = "full"),
                                  naive_bayes.GaussianNB(var_smoothing = 1e-09))
rf_pipe = pipeline.make_pipeline(preprocessing.MinMaxScaler(),
                                 ensemble.RandomForestClassifier(max_depth = None, max_features = 'log2', min_samples_leaf = 7))

estimators = [('svc', svc_pipe),
              ('lr', lr_pipe),
              ('knn', knn_pipe),
              ('gnb', gnb_pipe),
              ('rf', rf_pipe)]

stacker = ensemble.StackingClassifier(estimators = estimators, 
                                      final_estimator = linear_model.LogisticRegression(solver='liblinear'),
                                      passthrough = True)

stacker.fit(x, y_encoded)

# use pickle to save the model
final_stacking_model = stacker
pickle.dump(final_stacking_model, open('mood_stacking_model.sav', 'wb'))
