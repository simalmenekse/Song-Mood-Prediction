# %%
#Necessary imports for the feature_extraction
import os
import librosa
import numpy as np
import pandas as pd
import soundfile as sf
from pydub import AudioSegment

#PyAudioAnalysis
import pyAudioAnalysis as pyaudio
from pyAudioAnalysis import audioBasicIO
from pyAudioAnalysis import MidTermFeatures

# %%
# feature extraction data structures
features = []
existing_features = []
missing_features = []
previous_features = None

# %%
# check and save existing basic features
# check and save existing basic features
if os.path.exists("../data/features.csv"):
    previous_features = pd.read_csv("../data/features.csv")
    # drop all rows with any number of NAs
    previous_features.dropna(how = 'any')
    previous_features['song'] = previous_features['title'] + " - " + previous_features['artist']
    existing = previous_features['song'].tolist()

# %%
# feature extraction notebook should be in the same folder as the mp3s
for song in os.scandir("C:\\University\\Applied Machine Learning\\Project AML\\AppliedMachineLearning\\Main Project\\ProjectMusic"):
    if song.path.endswith(".mp3") and song.is_file():
        file_name = song.path[2:]
        song_name = file_name[98:len(file_name) - 4 ]

        if song_name not in existing_features:
            # add it to the missing list so we can use pyAudioAnalysis on it 
            missing_features.append(file_name)

            #tempo of the song
            waveform, sample_rate = librosa.load(file_name)
            tempo, beat_frames = librosa.beat.beat_track(y=waveform, sr=sample_rate)
             # get the chroma number of the song
            beat_times = librosa.frames_to_time(beat_frames, sr=sample_rate)
            y_harmonic, y_percussive = librosa.effects.hpss(waveform)
            chromagram = librosa.feature.chroma_cqt(y=y_harmonic, sr=sample_rate)
            beat_chroma = librosa.util.sync(chromagram, beat_frames, aggregate = np.median)
            # make beat chroma into a DataFrame and calculate the diff
            chroma_df = pd.DataFrame(beat_chroma)
            diff_values = chroma_df.diff()
            diff_mean = diff_values.mean(axis = 0, skipna = True)
            chroma_num = sum(diff_mean) / len(diff_mean)

            # add song, tempo and chroma number to the features list
            print ([song_name, tempo, chroma_num])
            features.append([song_name, tempo, chroma_num])
# Out:
# ['boy pablo - i hope she loves me back', 172.265625, -0.014764327699690405]
# ['Chase Shakur - Pray Slow', 80.74951171875, -0.0004073584414761695]
# ['Colin Stetson - Reborn', 143.5546875, -0.009726424886046749]
# ['Ethan Fields - Roll', 112.34714673913044, 0.013494097133865936]
# ['Home - 12', 89.10290948275862, 0.04064002817880582]
# ['Home - Byzantium', 135.99917763157896, 0.010142184480126814]
# ['Home - Drawing The Blinds', 89.10290948275862, -0.01080438335652505]
# ['Home - Head First', 135.99917763157896, -0.009489427418101144]
# ['Home - Intro', 99.38401442307692, -0.044663804797321814]
# ['Home - Resonance', 112.34714673913044, -0.02312311655040872]
# ['ITG Studios - Gravitational Forces', 135.99917763157896, -0.004196563845860897]
# ['Jakob - Sunshine Girl (Pt. 2)', 75.99954044117646, -0.015666099043745715]
# ['Jakob Ogawa - All Your Love', 86.1328125, -0.012112732377585773]
# ['Jakob Ogawa - You Might Be Sleeping (w. Clairo)', 92.28515625, -0.0034540407026909543]
# ['Jamie McDermott - In This Shirt', 161.4990234375, 0.0014778474502575676]
# ['Joy Again - Looking Out For You', 99.38401442307692, 0.009437577253664455]
# ['Kali Uchis - Feel Like A Fool', 107.666015625, -0.009557425001545506]
# ['Kali Uchis - i want war (BUT I NEED PEACE)', 89.10290948275862, -0.04676906906754075]
# ['Kali Uchis - Telepatia', 83.35433467741936, 0.021440045397004556]
# ['Lamp - Half Sleep', 95.703125, 0.010640254197395099]
# ['Laufey - From The Start', 107.666015625, -0.013683756873328146]
# ['Michael Jackson - Don’t Stop Til You Get Enough', 117.45383522727273, 0.030695144542443233]
# ['Michael Jackson - Leave Me Alone', 123.046875, 0.023046126872796256]
# ['Michael Jackson - Rock With You', 112.34714673913044, 0.007376815674628323]
# ['Micheal Jackson - Speed Demon', 99.38401442307692, -0.005173682058503308]
# ['Naruto - Gekiha', 117.45383522727273, -0.0034241527510953584]
# ['odyzon - sleepless', 172.265625, 0.011238645383469664]
# ['Paramore - Decode', 161.4990234375, -0.011963972371562714]
# ['Plums - Parking Lots', 151.99908088235293, 0.018691798830672512]
# ['Saib - Sao Paulo Sunset', 117.45383522727273, 0.011937027610866398]
# ['Silk Skin Lovers - Annie Chases a Butterfly', 129.19921875, 0.014116433212069585]
# ['SpongeBob - Bahia Baby', 107.666015625, 0.006064156101411025]
# ['SpongeBob - Epic Tragedy', 143.5546875, -0.01492651030277197]
# ['Strawberry Guy - F Song', 172.265625, -0.015071489046958512]
# ['SZA - Kill Bill', 89.10290948275862, -0.01298413671801362]
# ['The Glitch Mob - The White Stripes', 117.45383522727273, 0.0066732822286829484]
# ['TV Girl - Birds Dont Sing', 107.666015625, 0.014082066760680278]
# ['TV Girl - Blue Hair (sped up)', 107.666015625, -0.005826635627027617]
# ['TV Girl - Blue Hair', 135.99917763157896, 0.021435717096679272]
# ['TV Girl - Cigarettes out the Window', 117.45383522727273, -0.02810830902118418]
# ['TV Girl - Lovers Rock', 103.359375, -0.011971645807991774]
# ['TV Girl - Natalie Wood', 135.99917763157896, -0.009787856948709322]
# ['TV Girl - Not Allowed', 103.359375, -0.017937753189320494]
# ['Vacations - Actors', 151.99908088235293, 0.025784556156763297]
# ['Vacations - On Your Own', 143.5546875, 0.018562401332187423]
# ['Vacations - Steady', 151.99908088235293, -0.002419576853442255]
# ['VACATIONS - Telephones', 151.99908088235293, 0.00474352147161062]
# ['Yoshihisa Hirano - Kyrie', 129.19921875, -0.00810539179116285]
# ['Yot Club - Fly Out West', 172.265625, 0.010771384181091139]

# %%
len(features)
# Out:
# 49

# %%
features_df = pd.DataFrame(features, columns = ['song', 'tempo', 'chroma_number'])

# %%
features_df = features_df.sort_values(by = ['song'])

# %%
features_df.reset_index(drop = True, inplace = True)

# %%
features_df
# Out:
#                                                song       tempo  chroma_number
# 0                          Chase Shakur - Pray Slow   80.749512      -0.000407
# 1                            Colin Stetson - Reborn  143.554688      -0.009726
# 2                               Ethan Fields - Roll  112.347147       0.013494
# 3                                         Home - 12   89.102909       0.040640
# 4                                  Home - Byzantium  135.999178       0.010142
# 5                         Home - Drawing The Blinds   89.102909      -0.010804
# 6                                 Home - Head First  135.999178      -0.009489
# 7                                      Home - Intro   99.384014      -0.044664
# 8                                  Home - Resonance  112.347147      -0.023123
# 9                ITG Studios - Gravitational Forces  135.999178      -0.004197
# 10                    Jakob - Sunshine Girl (Pt. 2)   75.999540      -0.015666
# 11                      Jakob Ogawa - All Your Love   86.132812      -0.012113
# 12  Jakob Ogawa - You Might Be Sleeping (w. Clairo)   92.285156      -0.003454
# 13                  Jamie McDermott - In This Shirt  161.499023       0.001478
# 14                  Joy Again - Looking Out For You   99.384014       0.009438
# 15                    Kali Uchis - Feel Like A Fool  107.666016      -0.009557
# 16                           Kali Uchis - Telepatia   83.354335       0.021440
# 17       Kali Uchis - i want war (BUT I NEED PEACE)   89.102909      -0.046769
# 18                                Lamp - Half Sleep   95.703125       0.010640
# 19                          Laufey - From The Start  107.666016      -0.013684
# 20  Michael Jackson - Don’t Stop Til You Get Enough  117.453835       0.030695
# 21                 Michael Jackson - Leave Me Alone  123.046875       0.023046
# 22                  Michael Jackson - Rock With You  112.347147       0.007377
# 23                    Micheal Jackson - Speed Demon   99.384014      -0.005174
# 24                                  Naruto - Gekiha  117.453835      -0.003424
# 25                                Paramore - Decode  161.499023      -0.011964
# 26                             Plums - Parking Lots  151.999081       0.018692
# 27                                  SZA - Kill Bill   89.102909      -0.012984
# 28                          Saib - Sao Paulo Sunset  117.453835       0.011937
# 29      Silk Skin Lovers - Annie Chases a Butterfly  129.199219       0.014116
# 30                           SpongeBob - Bahia Baby  107.666016       0.006064
# 31                         SpongeBob - Epic Tragedy  143.554688      -0.014927
# 32                          Strawberry Guy - F Song  172.265625      -0.015071
# 33                        TV Girl - Birds Dont Sing  107.666016       0.014082
# 34                              TV Girl - Blue Hair  135.999178       0.021436
# 35                    TV Girl - Blue Hair (sped up)  107.666016      -0.005827
# 36              TV Girl - Cigarettes out the Window  117.453835      -0.028108
# 37                            TV Girl - Lovers Rock  103.359375      -0.011972
# 38                           TV Girl - Natalie Wood  135.999178      -0.009788
# 39                            TV Girl - Not Allowed  103.359375      -0.017938
# 40               The Glitch Mob - The White Stripes  117.453835       0.006673
# 41                           VACATIONS - Telephones  151.999081       0.004744
# 42                               Vacations - Actors  151.999081       0.025785
# 43                          Vacations - On Your Own  143.554688       0.018562
# 44                               Vacations - Steady  151.999081      -0.002420
# 45                         Yoshihisa Hirano - Kyrie  129.199219      -0.008105
# 46                          Yot Club - Fly Out West  172.265625       0.010771
# 47             boy pablo - i hope she loves me back  172.265625      -0.014764
# 48                               odyzon - sleepless  172.265625       0.011239

# %%
mid_term_window = 1
mid_term_step = 1
short_term_window = 0.05
short_term_step = 0.05
# use compute_beat = True if we want the extra beat features
pyaudio_feat, files, feat_names = MidTermFeatures.directory_feature_extraction("C:\\University\\Applied Machine Learning\\Project AML\\AppliedMachineLearning\\Main Project\\ProjectMusic", 
                                                                               mid_term_window, 
                                                                               mid_term_step, 
                                                                               short_term_window, 
                                                                               short_term_step,
                                                                               False)
# Out:
# Analyzing file 1 of 49: C:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMusic\Chase Shakur - Pray Slow.mp3
# Analyzing file 2 of 49: C:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMusic\Colin Stetson - Reborn.mp3
# Analyzing file 3 of 49: C:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMusic\Ethan Fields - Roll.mp3
# Analyzing file 4 of 49: C:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMusic\Home - 12.mp3
# Analyzing file 5 of 49: C:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMusic\Home - Byzantium.mp3
# Analyzing file 6 of 49: C:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMusic\Home - Drawing The Blinds.mp3
# Analyzing file 7 of 49: C:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMusic\Home - Head First.mp3
# Analyzing file 8 of 49: C:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMusic\Home - Intro.mp3
# Analyzing file 9 of 49: C:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMusic\Home - Resonance.mp3
# Analyzing file 10 of 49: C:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMusic\ITG Studios - Gravitational Forces.mp3
# Analyzing file 11 of 49: C:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMusic\Jakob - Sunshine Girl (Pt. 2).mp3
# Analyzing file 12 of 49: C:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMusic\Jakob Ogawa - All Your Love.mp3
# Analyzing file 13 of 49: C:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMusic\Jakob Ogawa - You Might Be Sleeping (w. Clairo).mp3
# Analyzing file 14 of 49: C:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMusic\Jamie McDermott - In This Shirt.mp3
# Analyzing file 15 of 49: C:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMusic\Joy Again - Looking Out For You.mp3
# Analyzing file 16 of 49: C:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMusic\Kali Uchis - Feel Like A Fool.mp3
# Analyzing file 17 of 49: C:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMusic\Kali Uchis - Telepatia.mp3
# Analyzing file 18 of 49: C:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMusic\Kali Uchis - i want war (BUT I NEED PEACE).mp3
# Analyzing file 19 of 49: C:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMusic\Lamp - Half Sleep.mp3
# Analyzing file 20 of 49: C:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMusic\Laufey - From The Start.mp3
# Analyzing file 21 of 49: C:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMusic\Michael Jackson - Don’t Stop Til You Get Enough.mp3
# Analyzing file 22 of 49: C:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMusic\Michael Jackson - Leave Me Alone.mp3
# Analyzing file 23 of 49: C:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMusic\Michael Jackson - Rock With You.mp3
# Analyzing file 24 of 49: C:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMusic\Micheal Jackson - Speed Demon.mp3
# Analyzing file 25 of 49: C:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMusic\Naruto - Gekiha.mp3
# Analyzing file 26 of 49: C:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMusic\Paramore - Decode.mp3
# Analyzing file 27 of 49: C:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMusic\Plums - Parking Lots.mp3
# Analyzing file 28 of 49: C:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMusic\SZA - Kill Bill.mp3
# Analyzing file 29 of 49: C:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMusic\Saib - Sao Paulo Sunset.mp3
# Analyzing file 30 of 49: C:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMusic\Silk Skin Lovers - Annie Chases a Butterfly.mp3
# Analyzing file 31 of 49: C:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMusic\SpongeBob - Bahia Baby.mp3
# Analyzing file 32 of 49: C:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMusic\SpongeBob - Epic Tragedy.mp3
# Analyzing file 33 of 49: C:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMusic\Strawberry Guy - F Song.mp3
# Analyzing file 34 of 49: C:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMusic\TV Girl - Birds Dont Sing.mp3
# Analyzing file 35 of 49: C:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMusic\TV Girl - Blue Hair (sped up).mp3
# Analyzing file 36 of 49: C:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMusic\TV Girl - Blue Hair.mp3
# Analyzing file 37 of 49: C:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMusic\TV Girl - Cigarettes out the Window.mp3
# Analyzing file 38 of 49: C:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMusic\TV Girl - Lovers Rock.mp3
# Analyzing file 39 of 49: C:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMusic\TV Girl - Natalie Wood.mp3
# Analyzing file 40 of 49: C:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMusic\TV Girl - Not Allowed.mp3
# Analyzing file 41 of 49: C:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMusic\The Glitch Mob - The White Stripes.mp3
# Analyzing file 42 of 49: C:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMusic\VACATIONS - Telephones.mp3
# Analyzing file 43 of 49: C:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMusic\Vacations - Actors.mp3
# Analyzing file 44 of 49: C:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMusic\Vacations - On Your Own.mp3
# Analyzing file 45 of 49: C:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMusic\Vacations - Steady.mp3
# Analyzing file 46 of 49: C:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMusic\Yoshihisa Hirano - Kyrie.mp3
# Analyzing file 47 of 49: C:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMusic\Yot Club - Fly Out West.mp3
# Analyzing file 48 of 49: C:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMusic\boy pablo - i hope she loves me back.mp3
# Analyzing file 49 of 49: C:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMusic\odyzon - sleepless.mp3
# Feature extraction complexity ratio: 44.7 x realtime

# %%
if len(features_df) == 1:
    # special case when only features from one song are extracted
    nn_features_df = pd.DataFrame([pyaudio_feat], columns = feat_names)
else:
    nn_features_df = pd.DataFrame(pyaudio_feat, columns = feat_names)
nn_features_df['song'] = features_df['song']

# %%
nn_features_df.head(5)
# Out:
#    zcr_mean  energy_mean  energy_entropy_mean  spectral_centroid_mean  \
# 0  0.022947     0.106520             3.149726                0.100529
# 1  0.040007     0.038373             3.212871                0.111733
# 2  0.031987     0.065058             3.123152                0.125037
# 3  0.010608     0.072424             3.085242                0.072542
# 4  0.038684     0.049714             3.150813                0.119300
#
#    spectral_spread_mean  spectral_entropy_mean  spectral_flux_mean  \
# 0              0.163562               0.141208            0.010873
# 1              0.161664               0.266827            0.003898
# 2              0.177614               0.224604            0.012203
# 3              0.147221               0.039320            0.009767
# 4              0.156493               0.378989            0.010054
#
#    spectral_rolloff_mean  mfcc_1_mean  mfcc_2_mean  ...  delta chroma_5_std  \
# 0               0.032800   -25.234294     2.963321  ...            0.014283
# 1               0.054467   -24.885468     2.254199  ...            0.008850
# 2               0.040521   -24.533269     2.750968  ...            0.016014
# 3               0.011183   -25.833940     3.845136  ...            0.021134
# 4               0.063881   -24.046810     1.263334  ...            0.010845
#
#    delta chroma_6_std  delta chroma_7_std  delta chroma_8_std  \
# 0            0.009444            0.054343            0.003779
# 1            0.014541            0.018126            0.004267
# 2            0.008040            0.074586            0.002541
# 3            0.003032            0.043249            0.001762
# 4            0.001922            0.084427            0.003541
#
#    delta chroma_9_std  delta chroma_10_std  delta chroma_11_std  \
# 0            0.005269             0.010572             0.022736
# 1            0.002583             0.007599             0.010553
# 2            0.014231             0.013226             0.026769
# 3            0.001266             0.011131             0.036833
# 4            0.008040             0.010516             0.050022
#
#    delta chroma_12_std  delta chroma_std_std                      song
# 0             0.004293              0.017441  Chase Shakur - Pray Slow
# 1             0.004186              0.007903    Colin Stetson - Reborn
# 2             0.013610              0.021303       Ethan Fields - Roll
# 3             0.000700              0.008889                 Home - 12
# 4             0.000929              0.020577          Home - Byzantium
#
# [5 rows x 137 columns]

# %%
# get the basic features by indexing into the neural network feature DataFrame
zcr_ind = feat_names.index('zcr_mean')
ee_ind = feat_names.index('energy_entropy_mean')
spc_ind = feat_names.index('spectral_centroid_mean')

features_df['zero_crossing_rate'] = nn_features_df.iloc[:, zcr_ind]
features_df['energy_entropy'] = nn_features_df.iloc[:, ee_ind]
features_df['spectral_centroid'] = nn_features_df.iloc[:, spc_ind]

# %%
features_df
# Out:
#                                                song       tempo  \
# 0                          Chase Shakur - Pray Slow   80.749512
# 1                            Colin Stetson - Reborn  143.554688
# 2                               Ethan Fields - Roll  112.347147
# 3                                         Home - 12   89.102909
# 4                                  Home - Byzantium  135.999178
# 5                         Home - Drawing The Blinds   89.102909
# 6                                 Home - Head First  135.999178
# 7                                      Home - Intro   99.384014
# 8                                  Home - Resonance  112.347147
# 9                ITG Studios - Gravitational Forces  135.999178
# 10                    Jakob - Sunshine Girl (Pt. 2)   75.999540
# 11                      Jakob Ogawa - All Your Love   86.132812
# 12  Jakob Ogawa - You Might Be Sleeping (w. Clairo)   92.285156
# 13                  Jamie McDermott - In This Shirt  161.499023
# 14                  Joy Again - Looking Out For You   99.384014
# 15                    Kali Uchis - Feel Like A Fool  107.666016
# 16                           Kali Uchis - Telepatia   83.354335
# 17       Kali Uchis - i want war (BUT I NEED PEACE)   89.102909
# 18                                Lamp - Half Sleep   95.703125
# 19                          Laufey - From The Start  107.666016
# 20  Michael Jackson - Don’t Stop Til You Get Enough  117.453835
# 21                 Michael Jackson - Leave Me Alone  123.046875
# 22                  Michael Jackson - Rock With You  112.347147
# 23                    Micheal Jackson - Speed Demon   99.384014
# 24                                  Naruto - Gekiha  117.453835
# 25                                Paramore - Decode  161.499023
# 40       0.006673            0.030427        3.089109           0.106161
# 41       0.004744            0.031469        3.186215           0.111889
# 42       0.025785            0.057919        3.199993           0.123717
# 43       0.018562            0.047829        3.184205           0.114829
# 44      -0.002420            0.051168        3.178251           0.116822
# 45      -0.008105            0.031372        3.225559           0.078180
# 46       0.010771            0.048201        3.189875           0.107196
# 47      -0.014764            0.044763        3.211649           0.115725
# 48       0.011239            0.012999        3.050920           0.073393

# %%
moods = pd.read_csv("./mood_data_main.csv")

# %%
moods['song'] = moods['artist'] + " - " + moods['title']
# sort the column song to use it for merging
moods = moods.sort_values(by = ['song'])
moods.reset_index(drop = True, inplace = True)

# %%
moods["song"]
# Out:
# 0                            Chase Shakur - Pray Slow
# 1                              Colin Stetson - Reborn
# 2                                 Ethan Fields - Roll
# 3                                           Home - 12
# 4                                    Home - Byzantium
# 5                           Home - Drawing The Blinds
# 6                                   Home - Head First
# 7                                        Home - Intro
# 8                                    Home - Resonance
# 9                  ITG Studios - Gravitational Forces
# 10                      Jakob - Sunshine Girl (Pt. 2)
# 11                        Jakob Ogawa - All Your Love
# 12    Jakob Ogawa - You Might Be Sleeping (w. Clairo)
# 13                    Jamie McDermott - In This Shirt
# 14                    Joy Again - Looking Out For You
# 15                      Kali Uchis - Feel Like A Fool
# 16                             Kali Uchis - Telepatia
# 17         Kali Uchis - i want war (BUT I NEED PEACE)
# 18                                  Lamp - Half Sleep
# 19                            Laufey - From The Start
# 20    Michael Jackson - Don’t Stop Til You Get Enough
# 21                   Michael Jackson - Leave Me Alone
# 22                    Michael Jackson - Rock With You
# 23                      Micheal Jackson - Speed Demon
# 24                                    Naruto - Gekiha
# 25                                  Paramore - Decode
# 26                               Plums - Parking Lots
# 27                                    SZA - Kill Bill
# 28                            Saib - Sao Paulo Sunset
# 29        Silk Skin Lovers - Annie Chases a Butterfly
# 30                             SpongeBob - Bahia Baby
# 31                           SpongeBob - Epic Tragedy
# 32                            Strawberry Guy - F Song
# 33                          TV Girl - Birds Dont Sing
# 34                                TV Girl - Blue Hair
# 35                      TV Girl - Blue Hair (sped up)
# 36                TV Girl - Cigarettes out the Window
# 37                              TV Girl - Lovers Rock
# 38                             TV Girl - Natalie Wood
# 39                              TV Girl - Not Allowed
# 40                 The Glitch Mob - The White Stripes
# 41                             VACATIONS - Telephones
# 42                                 Vacations - Actors
# 43                            Vacations - On Your Own
# 44                                 Vacations - Steady
# 45                           Yoshihisa Hirano - Kyrie
# 46                            Yot Club - Fly Out West
# 47               boy pablo - i hope she loves me back
# 48                                 odyzon - sleepless
# Name: song, dtype: object

# %%
moods.head(5)
# Out:
#        title         artist  primary  secondary                      song
# 0  Pray Slow   Chase Shakur        4          5  Chase Shakur - Pray Slow
# 1     Reborn  Colin Stetson        1          4    Colin Stetson - Reborn
# 2       Roll   Ethan Fields        2          3       Ethan Fields - Roll
# 3         12           Home        4          5                 Home - 12
# 4  Byzantium           Home        1          3          Home - Byzantium

# %%
len(features_df)
# Out:
# 49

# %%
new_features = features_df.merge(moods, on = "song", how = "left")
new_features = new_features.drop(columns = ['song'])
new_features
# Out:
#          tempo  chroma_number  zero_crossing_rate  energy_entropy  \
# 15           0.141314                   Feel Like A Fool        Kali Uchis
# 16           0.125280                          Telepatia        Kali Uchis
# 17           0.139181      i want war (BUT I NEED PEACE)        Kali Uchis
# 18           0.074314                         Half Sleep              Lamp
# 19           0.104290                     From The Start            Laufey
# 20           0.171270      Don’t Stop Til You Get Enough   Michael Jackson
# 21           0.163452                     Leave Me Alone   Michael Jackson
# 22           0.173464                      Rock With You   Michael Jackson
# 23           0.158451                        Speed Demon   Micheal Jackson
# 24           0.156072                             Gekiha            Naruto
# 25           0.134503                             Decode          Paramore
# 26           0.142785                       Parking Lots             Plums
# 27           0.103874                          Kill Bill               SZA
# 28           0.137236                   Sao Paulo Sunset              Saib
# 29           0.097304           Annie Chases a Butterfly  Silk Skin Lovers
# 30           0.095121                         Bahia Baby         SpongeBob
# 31           0.091566                       Epic Tragedy         SpongeBob
# 32           0.097753                             F Song    Strawberry Guy
# 33           0.134071                    Birds Dont Sing           TV Girl
# 34           0.132657                          Blue Hair           TV Girl
# 35           0.117554                Blue Hair (sped up)           TV Girl
# 36           0.149587          Cigarettes out the Window           TV Girl
# 37           0.141333                        Lovers Rock           TV Girl
# 38           0.148518                       Natalie Wood           TV Girl
# 39           0.098305                        Not Allowed           TV Girl
# 40           0.106161                  The White Stripes    The Glitch Mob
# 41           0.111889                         Telephones         VACATIONS
# 42           0.123717                             Actors         Vacations
# 43           0.114829                        On Your Own         Vacations
# 44           0.116822                             Steady         Vacations
# 45           0.078180                              Kyrie  Yoshihisa Hirano
# 46           0.107196                       Fly Out West          Yot Club
# 47           0.115725           i hope she loves me back         boy pablo
# 48           0.073393                          sleepless            odyzon
#
#     primary  secondary
# 0         4          5
# 1         1          4
# 2         2          3
# 3         4          5
# 4         1          3
# 5         2          4
# 6         1          2
# 7         2          4
# 8         2          5
# 9         1          6
# 10        2          4
# 11        4          5
# 12        2          4
# 13        1          6
# 14        2          3
# 15        2          5
# 16        2          4
# 17        4          5
# 18        2          4
# 19        2          6
# 20        3          6
# 21        3          6
# 22        2          4
# 23        3          6
# 24        1          3
# 25        1          3
# 26        3          6
# 27        2          4
# 28        2          6
# 29        3          4
# 30        2          4
# 31        1          6
# 32        4          5
# 33        2          3
# 34        2          3
# 35        3          6
# 36        2          3
# 37        2          3
# 38        3          6
# 39        3          4
# 40        1          6
# 41        4          5
# 42        3          6
# 43        3          4
# 44        2          3
# 45        1          6
# 46        3          6
# 47        2          3
# 48        4          5

# %%
# save the basic features, neural network features and the feature names
if not existing_features:
    new_features = new_features[['title', 'artist', 'tempo', 'chroma_number', 
                                 'zero_crossing_rate', 'energy_entropy', 
                                 'spectral_centroid', 'primary', 'secondary']]
    new_features.to_csv("../data/features.csv", header = True, index = False)
    
    nn_features_df.to_csv("../data/nn_features.csv", header = True, index = False)
    
    feat_names_df = pd.DataFrame(feat_names)
    feat_names_df.to_csv("../data/nn_feature_names.csv", header = True, index = False)
else:
    # concatenate the previous features with new features and overwrite the existing files
    previous_features = previous_features.drop(columns = ['song'])
    all_features = pd.concat([previous_features, new_features], ignore_index = True)
    all_features = all_features[['title', 'artist', 'tempo', 'chroma_number', 
                                 'zero_crossing_rate', 'energy_entropy', 
                                 'spectral_centroid', 'primary', 'secondary']]
    all_features.to_csv("../data/features.csv", header = True, index = False)
    
    prev_nn = pd.read_csv("../data/nn_features.csv")
    all_nn = pd.concat([prev_nn, nn_features_df], ignore_index = True)
    all_nn.to_csv("../data/nn_features.csv", header = True, index = False)

# %%
engineered_features
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\University\Applied Machine Learning\Project AML\AppliedMachineLearning\Main Project\ProjectMainCodeFiles\feature_extraction_main.ipynb Cell 22 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/University/Applied%20Machine%20Learning/Project%20AML/AppliedMachineLearning/Main%20Project/ProjectMainCodeFiles/feature_extraction_main.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> engineered_features
#
# NameError: name 'engineered_features' is not defined

# %%
# feature engineering
feat_names_df = pd.read_csv("../data/nn_feature_names.csv")
current_features = pd.read_csv("../data/features.csv")
feats_to_extract = pd.read_csv("../data/nn_features.csv")
engineered_features = current_features[['title', 'artist', 'tempo', 'chroma_number']]

# check that the ordering of songs is the same
engineered_features['song'] = feats_to_extract['song']
engineered_features['song_check'] = engineered_features['artist'] + ' - ' + engineered_features['title']
if engineered_features['song'].equals(engineered_features['song_check']):
    print ("Song ordering matches.")
    engineered_features = engineered_features.drop(columns = ['song', 'song_check'])
else:
    print ("Song ordering DOES NOT match.")

# convert the feature names into a list
feat_names_list = feat_names_df['0'].to_list()
# selected 28 total features based on distribution boxplots by primary mood
selected_feats = ['zcr_mean', 'zcr_std', 'energy_mean', 'energy_entropy_mean', 'spectral_centroid_mean', 
                  'spectral_spread_mean', 'spectral_entropy_mean', 'mfcc_2_mean', 'mfcc_5_mean', 'mfcc_6_mean',
                  'spectral_centroid_std', 'spectral_entropy_std', 'spectral_spread_std', 'chroma_7_std',
                  'delta chroma_2_std', 'delta chroma_3_std', 'delta chroma_9_std', 'delta chroma_std_std',
                  'delta energy_std', 'delta mfcc_1_std', 'delta mfcc_3_std', 'delta mfcc_13_std',
                  'delta spectral_centroid_std', 'delta spectral_entropy_std', 'delta spectral_flux_std',
                  'delta spectral_spread_std']
for feat in selected_feats:
    engineered_features[feat] = feats_to_extract.iloc[:, feat_names_list.index(feat)]

# add mood labels to the final features dataframe
engineered_features['primary'] = current_features['primary']
engineered_features['secondary'] = current_features['secondary']

# save the engineered features
engineered_features.to_csv("../data/engineered_features.csv", header = True, index = False)
engineered_features
# Out:
# Song ordering matches.
# C:\Users\HP\AppData\Local\Temp\ipykernel_26968\169539312.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   engineered_features['song'] = feats_to_extract['song']
# C:\Users\HP\AppData\Local\Temp\ipykernel_26968\169539312.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   engineered_features['song_check'] = engineered_features['artist'] + ' - ' + engineered_features['title']
#                                 title            artist       tempo  \
# 0                           Pray Slow      Chase Shakur   80.749512
# 1                              Reborn     Colin Stetson  143.554688
# 2                                Roll      Ethan Fields  112.347147
# 3                                  12              Home   89.102909
# 4                           Byzantium              Home  135.999178
# 5                  Drawing The Blinds              Home   89.102909
# 6                          Head First              Home  135.999178
# 7                               Intro              Home   99.384014
# 8                           Resonance              Home  112.347147
# 9                Gravitational Forces       ITG Studios  135.999178
# 10              Sunshine Girl (Pt. 2)             Jakob   75.999540
# 11                      All Your Love       Jakob Ogawa   86.132812
# 22       0.007377  0.084850  0.048060     0.028057             3.113855
# 23      -0.005174  0.065211  0.032353     0.014864             3.011945
# 24      -0.003424  0.074282  0.021425     0.045190             3.100833
# 25      -0.011964  0.063210  0.018241     0.070602             3.211475
# 26       0.018692  0.070227  0.018141     0.048256             3.224220
# 27      -0.012984  0.034008  0.014650     0.097648             3.188648
# 28       0.011937  0.047851  0.030213     0.035286             3.061098
# 29       0.014116  0.028824  0.010407     0.057643             3.185343
# 30       0.006064  0.028205  0.009624     0.022862             3.124335
# 31      -0.014927  0.046403  0.007925     0.084409             3.253214
# 32      -0.015071  0.040241  0.014615     0.020750             3.184216
# 33       0.014082  0.058893  0.025920     0.074389             3.171878
# 34       0.021436  0.050455  0.024441     0.053851             3.158151
# 35      -0.005827  0.042319  0.020367     0.050990             3.146260
# 36      -0.028108  0.060634  0.029603     0.080946             3.166267
# 37      -0.011972  0.057898  0.020292     0.070414             3.115839
# 38      -0.009788  0.061780  0.030581     0.048931             3.117142
# 39      -0.017938  0.035049  0.012080     0.083578             3.158445
# 40       0.006673  0.030427  0.012525     0.093654             3.089109
# 41       0.004744  0.031469  0.013948     0.040424             3.186215
# 42       0.025785  0.057919  0.016338     0.067781             3.199993
# 43       0.018562  0.047829  0.015240     0.072566             3.184205
# 44      -0.002420  0.051168  0.017305     0.031393             3.178251
# 45      -0.008105  0.031372  0.006792     0.024577             3.225559
# 46       0.010771  0.048201  0.013682     0.033920             3.189875
# 47      -0.014764  0.044763  0.013199     0.041024             3.211649
# 48       0.011239  0.012999  0.002638     0.049038             3.050920
#
#     spectral_centroid_mean  spectral_spread_mean  ...  delta energy_std  \
# 0                 0.100529              0.163562  ...          0.059472
# 1                 0.111733              0.161664  ...          0.007091
# 2                 0.125037              0.177614  ...          0.048894
# 3                 0.072542              0.147221  ...          0.012299
# 4                 0.119300              0.156493  ...          0.037722
# 5                 0.123426              0.169007  ...          0.031561
# 6                 0.100086              0.146246  ...          0.042732
# 7                 0.075927              0.141992  ...          0.010922
# 8                 0.078118              0.145261  ...          0.061921
# 9                 0.093822              0.165921  ...          0.020140
# 10                0.098135              0.173398  ...          0.040459
# 11                0.098540              0.154144  ...          0.072326
# 12                0.090017              0.152228  ...          0.056132
# 13                0.101307              0.146256  ...          0.010183
# 14                0.112675              0.152273  ...          0.048726
# 15                0.141314              0.174628  ...          0.054925
# 16                0.125280              0.172543  ...          0.041625
# 17                0.139181              0.189971  ...          0.017018
# 18                0.074314              0.148099  ...          0.013158
# 19                0.104290              0.166358  ...          0.047981
# 20                0.171270              0.177588  ...          0.039447
# 21                0.163452              0.180366  ...          0.041832
# 22                0.173464              0.187984  ...          0.040259
# 23                0.158451              0.178278  ...          0.016110
# 24                0.156072              0.163859  ...          0.027212
# 25                0.134503              0.159684  ...          0.024046
# 26                0.142785              0.162099  ...          0.025957
# 27                0.103874              0.152463  ...          0.067396
# 28                0.137236              0.179073  ...          0.038734
# 29                0.097304              0.155532  ...          0.016898
# 30                0.095121              0.152155  ...          0.013406
# 31                0.091566              0.130186  ...          0.022693
# 32                0.097753              0.139942  ...          0.010051
# 14                     0.025824                    0.217929
# 15                     0.030915                    0.240832
# 16                     0.039103                    0.253565
# 17                     0.037777                    0.168772
# 18                     0.034934                    0.024964
# 19                     0.037711                    0.181799
# 20                     0.052627                    0.586013
# 21                     0.033635                    0.318065
# 22                     0.054876                    0.426275
# 23                     0.044898                    0.480349
# 24                     0.020575                    0.272522
# 25                     0.021748                    0.186131
# 26                     0.022801                    0.210833
# 27                     0.028798                    0.148924
# 28                     0.045849                    0.318880
# 29                     0.032327                    0.117144
# 30                     0.033304                    0.117662
# 31                     0.022703                    0.097966
# 32                     0.024998                    0.156137
# 33                     0.031525                    0.295569
# 34                     0.030511                    0.287007
# 35                     0.027594                    0.232653
# 36                     0.047779                    0.273258
# 37                     0.033594                    0.236103
# 38                     0.032125                    0.327639
# 39                     0.025128                    0.125223
# 40                     0.025784                    0.119487
# 41                     0.038182                    0.132588
# 42                     0.026543                    0.226886
# 43                     0.029224                    0.167376
# 44                     0.033764                    0.199101
# 45                     0.025473                    0.062220
# 46                     0.023239                    0.167442
# 47                     0.024531                    0.142183
# 48                     0.033923                    0.019294
#
#     delta spectral_flux_std  delta spectral_spread_std  primary  secondary
# 0                  0.013225                   0.048587        4          5
# 1                  0.002462                   0.035453        1          4
# 2                  0.014551                   0.041004        2          3
# 3                  0.019458                   0.045563        4          5
# 4                  0.013648                   0.043370        1          3
# 5                  0.010030                   0.029254        2          4
# 6                  0.009717                   0.043519        1          2
# 7                  0.008715                   0.054390        2          4
# 8                  0.012369                   0.057298        2          5
# 9                  0.007262                   0.045157        1          6
# 10                 0.013057                   0.043618        2          4
# 11                 0.016616                   0.041627        4          5
# 12                 0.008787                   0.040730        2          4
# 13                 0.002756                   0.033167        1          6
# 14                 0.005729                   0.030969        2          3
# 15                 0.004950                   0.023935        2          5
# 16                 0.010692                   0.032150        2          4
# 17                 0.005221                   0.031857        4          5
# 18                 0.010059                   0.057260        2          4
# 19                 0.012685                   0.038141        2          6
# 20                 0.007212                   0.028700        3          6
# 21                 0.004396                   0.029813        3          6
# 22                 0.006744                   0.034602        2          4
# 23                 0.008136                   0.033115        3          6
# 24                 0.004613                   0.019570        1          3
# 25                 0.003926                   0.023668        1          3
# 26                 0.003541                   0.025344        3          6
# 27                 0.010436                   0.036243        2          4
# 28                 0.007520                   0.030125        2          6
# 29                 0.006602                   0.043784        3          4
# 30                 0.009878                   0.041355        2          4
# 31                 0.005568                   0.043690        1          6
# 32                 0.003787                   0.037699        4          5
# 33                 0.004814                   0.028093        2          3
# 34                 0.004875                   0.026996        2          3
# 35                 0.005376                   0.032460        3          6
# 36                 0.006366                   0.034208        2          3
# 37                 0.003487                   0.029839        2          3
# 38                 0.006187                   0.026784        3          6
# 39                 0.005869                   0.035305        3          4
# 40                 0.006660                   0.033953        1          6
# 41                 0.007709                   0.040821        4          5
# 42                 0.005376                   0.028423        3          6
# 43                 0.005348                   0.034463        3          4
# 44                 0.009519                   0.035519        2          3
# 45                 0.009863                   0.045756        1          6
# 46                 0.005220                   0.033686        3          6
# 47                 0.006177                   0.029793        2          3
# 48                 0.007674                   0.053438        4          5
#
# [49 rows x 32 columns]
