# %%
#Necessary imports for the feature_extraction
import os
import librosa
import numpy as np
import pandas as pd
import soundfile as sf
from pydub import AudioSegment

#PyAudioAnalysis
import pyAudioAnalysis as pyaudio
from pyAudioAnalysis import audioBasicIO
from pyAudioAnalysis import MidTermFeatures

# %%
# feature extraction data structures
features = []
existing_features = []
missing_features = []
previous_features = None

# %%
# check and save existing basic features
# check and save existing basic features
if os.path.exists("../data/features.csv"):
    previous_features = pd.read_csv("../data/features.csv")
    # drop all rows with any number of NAs
    previous_features.dropna(how = 'any')
    previous_features['song'] = previous_features['title'] + " - " + previous_features['artist']
    existing = previous_features['song'].tolist()

# %%
# feature extraction notebook should be in the same folder as the mp3s
for song in os.scandir("C:\\Users\\HP\\OneDrive\\Music\\ProjectMusic"):
    if song.path.endswith(".mp3") and song.is_file():
        file_name = song.path[2:]
        song_name = file_name[38:len(file_name) - 4 ]

        if song_name not in existing_features:
            # add it to the missing list so we can use pyAudioAnalysis on it 
            missing_features.append(file_name)

            #tempo of the song
            waveform, sample_rate = librosa.load(file_name)
            tempo, beat_frames = librosa.beat.beat_track(y=waveform, sr=sample_rate)
             # get the chroma number of the song
            beat_times = librosa.frames_to_time(beat_frames, sr=sample_rate)
            y_harmonic, y_percussive = librosa.effects.hpss(waveform)
            chromagram = librosa.feature.chroma_cqt(y=y_harmonic, sr=sample_rate)
            beat_chroma = librosa.util.sync(chromagram, beat_frames, aggregate = np.median)
            # make beat chroma into a DataFrame and calculate the diff
            chroma_df = pd.DataFrame(beat_chroma)
            diff_values = chroma_df.diff()
            diff_mean = diff_values.mean(axis = 0, skipna = True)
            chroma_num = sum(diff_mean) / len(diff_mean)

            # add song, tempo and chroma number to the features list
            print ([song_name, tempo, chroma_num])
            features.append([song_name, tempo, chroma_num])
# Out:
# ['boy pablo - i hope she loves me back', 172.265625, -0.014764327699690405]
# ['Chase Shakur - Pray Slow', 80.74951171875, -0.0004073584414761695]
# ['Jakob Ogawa - All Your Love', 86.1328125, -0.012112732377585773]
# ['Joy Again - Looking Out For You', 99.38401442307692, 0.009437577253664455]
# ['Kali Uchis - Feel Like A Fool', 107.666015625, -0.009557425001545506]
# ['Kali Uchis - i want war (BUT I NEED PEACE)', 89.10290948275862, -0.04676906906754075]
# ['Kali Uchis - Telepatía', 83.35433467741936, 0.021440045397004556]
# ['Plums - Parking Lots', 151.99908088235293, 0.018691798830672512]
# ['Silk Skin Lovers - Annie Chases a Butterfly', 129.19921875, 0.014116433212069585]
# ['Silk Skin Lovers - Moon, 1AM', 107.666015625, -0.022236840030682846]
# ['Strawberry Guy - F Song', 172.265625, -0.015071489046958512]
# ['TV Girl - Birds Dont Sing', 107.666015625, 0.014082066760680278]
# ['TV Girl - Blue Hair (sped up)', 107.666015625, -0.005826635627027617]
# ['TV Girl - Blue Hair', 135.99917763157896, 0.021435717096679272]
# ['TV Girl - Cigarettes out the Window', 117.45383522727273, -0.02810830902118418]
# ['TV Girl - Lovers Rock', 103.359375, -0.011971645807991774]
# ['TV Girl - Natalie Wood', 135.99917763157896, -0.009787856948709322]
# ['TV Girl - Not Allowed', 103.359375, -0.017937753189320494]
# ['Vacations - Actors', 151.99908088235293, 0.025784556156763297]
# ['Vacations - On Your Own', 143.5546875, 0.018562401332187423]
# ['VACATIONS - Telephones', 151.99908088235293, 0.00474352147161062]
# ['Yot Club - Fly Out West', 172.265625, 0.010771384181091139]

# %%
features_df = pd.DataFrame(features, columns = ['song', 'tempo', 'chroma_number'])

# %%
features_df = features_df.sort_values(by = ['song'])

# %%
features_df.reset_index(drop = True, inplace = True)

# %%
features_df
# Out:
#                                            song       tempo  chroma_number
# 0                      Chase Shakur - Pray Slow   80.749512      -0.000407
# 1                   Jakob Ogawa - All Your Love   86.132812      -0.012113
# 2               Joy Again - Looking Out For You   99.384014       0.009438
# 3                 Kali Uchis - Feel Like A Fool  107.666016      -0.009557
# 4                        Kali Uchis - Telepatía   83.354335       0.021440
# 5    Kali Uchis - i want war (BUT I NEED PEACE)   89.102909      -0.046769
# 6                          Plums - Parking Lots  151.999081       0.018692
# 7   Silk Skin Lovers - Annie Chases a Butterfly  129.199219       0.014116
# 8                  Silk Skin Lovers - Moon, 1AM  107.666016      -0.022237
# 9                       Strawberry Guy - F Song  172.265625      -0.015071
# 10                    TV Girl - Birds Dont Sing  107.666016       0.014082
# 11                          TV Girl - Blue Hair  135.999178       0.021436
# 12                TV Girl - Blue Hair (sped up)  107.666016      -0.005827
# 13          TV Girl - Cigarettes out the Window  117.453835      -0.028108
# 14                        TV Girl - Lovers Rock  103.359375      -0.011972
# 15                       TV Girl - Natalie Wood  135.999178      -0.009788
# 16                        TV Girl - Not Allowed  103.359375      -0.017938
# 17                       VACATIONS - Telephones  151.999081       0.004744
# 18                           Vacations - Actors  151.999081       0.025785
# 19                      Vacations - On Your Own  143.554688       0.018562
# 20                      Yot Club - Fly Out West  172.265625       0.010771
# 21         boy pablo - i hope she loves me back  172.265625      -0.014764

# %%
mid_term_window = 1
mid_term_step = 1
short_term_window = 0.05
short_term_step = 0.05
# use compute_beat = True if we want the extra beat features
pyaudio_feat, files, feat_names = MidTermFeatures.directory_feature_extraction("C:\\Users\\HP\\OneDrive\\Music\\ProjectMusic", 
                                                                               mid_term_window, 
                                                                               mid_term_step, 
                                                                               short_term_window, 
                                                                               short_term_step,
                                                                               False)
# Out:
# Analyzing file 1 of 22: C:\Users\HP\OneDrive\Music\ProjectMusic\Chase Shakur - Pray Slow.mp3
# Analyzing file 2 of 22: C:\Users\HP\OneDrive\Music\ProjectMusic\Jakob Ogawa - All Your Love.mp3
# Analyzing file 3 of 22: C:\Users\HP\OneDrive\Music\ProjectMusic\Joy Again - Looking Out For You.mp3
# Analyzing file 4 of 22: C:\Users\HP\OneDrive\Music\ProjectMusic\Kali Uchis - Feel Like A Fool.mp3
# Analyzing file 5 of 22: C:\Users\HP\OneDrive\Music\ProjectMusic\Kali Uchis - Telepatía.mp3
# Analyzing file 6 of 22: C:\Users\HP\OneDrive\Music\ProjectMusic\Kali Uchis - i want war (BUT I NEED PEACE).mp3
# Analyzing file 7 of 22: C:\Users\HP\OneDrive\Music\ProjectMusic\Plums - Parking Lots.mp3
# Analyzing file 8 of 22: C:\Users\HP\OneDrive\Music\ProjectMusic\Silk Skin Lovers - Annie Chases a Butterfly.mp3
# Analyzing file 9 of 22: C:\Users\HP\OneDrive\Music\ProjectMusic\Silk Skin Lovers - Moon, 1AM.mp3
# Analyzing file 10 of 22: C:\Users\HP\OneDrive\Music\ProjectMusic\Strawberry Guy - F Song.mp3
# Analyzing file 11 of 22: C:\Users\HP\OneDrive\Music\ProjectMusic\TV Girl - Birds Dont Sing.mp3
# Analyzing file 12 of 22: C:\Users\HP\OneDrive\Music\ProjectMusic\TV Girl - Blue Hair (sped up).mp3
# Analyzing file 13 of 22: C:\Users\HP\OneDrive\Music\ProjectMusic\TV Girl - Blue Hair.mp3
# Analyzing file 14 of 22: C:\Users\HP\OneDrive\Music\ProjectMusic\TV Girl - Cigarettes out the Window.mp3
# Analyzing file 15 of 22: C:\Users\HP\OneDrive\Music\ProjectMusic\TV Girl - Lovers Rock.mp3
# Analyzing file 16 of 22: C:\Users\HP\OneDrive\Music\ProjectMusic\TV Girl - Natalie Wood.mp3
# Analyzing file 17 of 22: C:\Users\HP\OneDrive\Music\ProjectMusic\TV Girl - Not Allowed.mp3
# Analyzing file 18 of 22: C:\Users\HP\OneDrive\Music\ProjectMusic\VACATIONS - Telephones.mp3
# Analyzing file 19 of 22: C:\Users\HP\OneDrive\Music\ProjectMusic\Vacations - Actors.mp3
# Analyzing file 20 of 22: C:\Users\HP\OneDrive\Music\ProjectMusic\Vacations - On Your Own.mp3
# Analyzing file 21 of 22: C:\Users\HP\OneDrive\Music\ProjectMusic\Yot Club - Fly Out West.mp3
# Analyzing file 22 of 22: C:\Users\HP\OneDrive\Music\ProjectMusic\boy pablo - i hope she loves me back.mp3
# Feature extraction complexity ratio: 23.4 x realtime

# %%
if len(features_df) == 1:
    # special case when only features from one song are extracted
    nn_features_df = pd.DataFrame([pyaudio_feat], columns = feat_names)
else:
    nn_features_df = pd.DataFrame(pyaudio_feat, columns = feat_names)
nn_features_df['song'] = features_df['song']

# %%
nn_features_df.head(5)
# Out:
#    zcr_mean  energy_mean  energy_entropy_mean  spectral_centroid_mean  \
# 0  0.022947     0.106520             3.149726                0.100529
# 1  0.032611     0.067622             3.093993                0.098540
# 2  0.045941     0.075397             3.109662                0.112675
# 3  0.055727     0.084506             3.166845                0.141314
# 4  0.039607     0.069749             3.146406                0.125280
#
#    spectral_spread_mean  spectral_entropy_mean  spectral_flux_mean  \
# 0              0.163562               0.141208            0.010873
# 1              0.154144               0.190479            0.013278
# 2              0.152273               0.383828            0.006020
# 3              0.174628               0.389772            0.005715
# 4              0.172543               0.283957            0.009572
#
#    spectral_rolloff_mean  mfcc_1_mean  mfcc_2_mean  ...  delta chroma_5_std  \
# 0               0.032800   -25.234294     2.963321  ...            0.014283
# 1               0.045232   -24.667007     1.887863  ...            0.024552
# 2               0.064533   -23.623992     2.039796  ...            0.018687
# 3               0.073480   -22.589133     1.727771  ...            0.029955
# 4               0.055347   -24.531567     2.186144  ...            0.020148
#
#    delta chroma_6_std  delta chroma_7_std  delta chroma_8_std  \
# 0            0.009444            0.054343            0.003779
# 1            0.007863            0.066818            0.010377
# 2            0.013854            0.036684            0.007490
# 3            0.005676            0.057613            0.004056
# 4            0.010359            0.065734            0.002650
#
#    delta chroma_9_std  delta chroma_10_std  delta chroma_11_std  \
# 0            0.005269             0.010572             0.022736
# 1            0.017183             0.021579             0.041195
# 2            0.013700             0.024799             0.025054
# 3            0.009966             0.015739             0.042998
# 4            0.007440             0.025936             0.032301
#
#    delta chroma_12_std  delta chroma_std_std                             song
# 0             0.004293              0.017441         Chase Shakur - Pray Slow
# 1             0.003499              0.019393      Jakob Ogawa - All Your Love
# 2             0.004519              0.010691  Joy Again - Looking Out For You
# 3             0.009062              0.014815    Kali Uchis - Feel Like A Fool
# 4             0.003936              0.016601           Kali Uchis - Telepatía
#
# [5 rows x 137 columns]

# %%
# get the basic features by indexing into the neural network feature DataFrame
zcr_ind = feat_names.index('zcr_mean')
ee_ind = feat_names.index('energy_entropy_mean')
spc_ind = feat_names.index('spectral_centroid_mean')

features_df['zero_crossing_rate'] = nn_features_df.iloc[:, zcr_ind]
features_df['energy_entropy'] = nn_features_df.iloc[:, ee_ind]
features_df['spectral_centroid'] = nn_features_df.iloc[:, spc_ind]

# %%
features_df["song"]
# Out:
# 0                        Chase Shakur - Pray Slow
# 1                     Jakob Ogawa - All Your Love
# 2                 Joy Again - Looking Out For You
# 3                   Kali Uchis - Feel Like A Fool
# 4                          Kali Uchis - Telepatía
# 5      Kali Uchis - i want war (BUT I NEED PEACE)
# 6                            Plums - Parking Lots
# 7     Silk Skin Lovers - Annie Chases a Butterfly
# 8                    Silk Skin Lovers - Moon, 1AM
# 9                         Strawberry Guy - F Song
# 10                      TV Girl - Birds Dont Sing
# 11                            TV Girl - Blue Hair
# 12                  TV Girl - Blue Hair (sped up)
# 13            TV Girl - Cigarettes out the Window
# 14                          TV Girl - Lovers Rock
# 15                         TV Girl - Natalie Wood
# 16                          TV Girl - Not Allowed
# 17                         VACATIONS - Telephones
# 18                             Vacations - Actors
# 19                        Vacations - On Your Own
# 20                        Yot Club - Fly Out West
# 21           boy pablo - i hope she loves me back
# Name: song, dtype: object

# %%
moods = pd.read_csv("./mood_data_main.csv")

# %%
moods['song'] = moods['artist'] + " - " + moods['title']
# sort the column song to use it for merging
moods = moods.sort_values(by = ['song'])
moods.reset_index(drop = True, inplace = True)

# %%
moods["song"]
# Out:
# 0                        Chase Shakur - Pray Slow
# 1                     Jakob Ogawa - All Your Love
# 2                 Joy Again - Looking Out For You
# 3                   Kali Uchis - Feel Like A Fool
# 4                          Kali Uchis - Telepatía
# 5      Kali Uchis - i want war (BUT I NEED PEACE)
# 6                            Plums - Parking Lots
# 7     Silk Skin Lovers - Annie Chases a Butterfly
# 8                     Silk Skin Lovers - Moon 1AM
# 9                         Strawberry Guy - F Song
# 10                      TV Girl - Birds Dont Sing
# 11                            TV Girl - Blue Hair
# 12                  TV Girl - Blue Hair (sped up)
# 13            TV Girl - Cigarettes out the Window
# 14                          TV Girl - Lovers Rock
# 15                         TV Girl - Natalie Wood
# 16                          TV Girl - Not Allowed
# 17                         VACATIONS - Telephones
# 18                             Vacations - Actors
# 19                        Vacations - On Your Own
# 20                        Yot Club - Fly Out West
# 21           boy pablo - i hope she loves me back
# Name: song, dtype: object

# %%
moods.head(5)
# Out:
#                  title        artist  primary  secondary  \
# 0            Pray Slow  Chase Shakur        3          4
# 1        All Your Love   Jakob Ogawa        1          3
# 2  Looking Out For You     Joy Again        4          2
# 3     Feel Like A Fool    Kali Uchis        1          6
# 4            Telepatía    Kali Uchis        1          5
#
#                               song
# 0         Chase Shakur - Pray Slow
# 1      Jakob Ogawa - All Your Love
# 2  Joy Again - Looking Out For You
# 3    Kali Uchis - Feel Like A Fool
# 4           Kali Uchis - Telepatía

# %%
features_df.head(5)
# Out:
#                               song       tempo  chroma_number  \
# 0         Chase Shakur - Pray Slow   80.749512      -0.000407
# 1      Jakob Ogawa - All Your Love   86.132812      -0.012113
# 2  Joy Again - Looking Out For You   99.384014       0.009438
# 3    Kali Uchis - Feel Like A Fool  107.666016      -0.009557
# 4           Kali Uchis - Telepatía   83.354335       0.021440
#
#    zero_crossing_rate  energy_entropy  spectral_centroid
# 0            0.022947        3.149726           0.100529
# 1            0.032611        3.093993           0.098540
# 2            0.045941        3.109662           0.112675
# 3            0.055727        3.166845           0.141314
# 4            0.039607        3.146406           0.125280

# %%
new_features = features_df.merge(moods, on = "song", how = "left")
new_features = new_features.drop(columns = ['song'])
new_features
# Out:
#          tempo  chroma_number  zero_crossing_rate  energy_entropy  \
# 0    80.749512      -0.000407            0.022947        3.149726
# 1    86.132812      -0.012113            0.032611        3.093993
# 2    99.384014       0.009438            0.045941        3.109662
# 3   107.666016      -0.009557            0.055727        3.166845
# 4    83.354335       0.021440            0.039607        3.146406
# 5    89.102909      -0.046769            0.044189        3.124969
# 6   151.999081       0.018692            0.070227        3.224220
# 7   129.199219       0.014116            0.028824        3.185343
# 8   107.666016      -0.022237            0.041632        3.141644
# 9   172.265625      -0.015071            0.040241        3.184216
# 10  107.666016       0.014082            0.058893        3.171878
# 11  135.999178       0.021436            0.050455        3.158151
# 12  107.666016      -0.005827            0.042319        3.146260
# 13  117.453835      -0.028108            0.060634        3.166267
# 14  103.359375      -0.011972            0.057898        3.115839
# 15  135.999178      -0.009788            0.061780        3.117142
# 16  103.359375      -0.017938            0.035049        3.158445
# 17  151.999081       0.004744            0.031469        3.186215
# 18  151.999081       0.025785            0.057919        3.199993
# 19  143.554688       0.018562            0.047829        3.184205
# 20  172.265625       0.010771            0.048201        3.189875
# 21  172.265625      -0.014764            0.044763        3.211649
#
#     spectral_centroid                          title            artist  \
# 0            0.100529                      Pray Slow      Chase Shakur
# 1            0.098540                  All Your Love       Jakob Ogawa
# 2            0.112675            Looking Out For You         Joy Again
# 3            0.141314               Feel Like A Fool        Kali Uchis
# 4            0.125280                      Telepatía        Kali Uchis
# 5            0.139181  i want war (BUT I NEED PEACE)        Kali Uchis
# 6            0.142785                   Parking Lots             Plums
# 7            0.097304       Annie Chases a Butterfly  Silk Skin Lovers
# 8            0.105148                            NaN               NaN
# 9            0.097753                         F Song    Strawberry Guy
# 10           0.134071                Birds Dont Sing           TV Girl
# 11           0.132657                      Blue Hair           TV Girl
# 12           0.117554            Blue Hair (sped up)           TV Girl
# 13           0.149587      Cigarettes out the Window           TV Girl
# 14           0.141333                    Lovers Rock           TV Girl
# 15           0.148518                   Natalie Wood           TV Girl
# 16           0.098305                    Not Allowed           TV Girl
# 17           0.111889                     Telephones         VACATIONS
# 18           0.123717                         Actors         Vacations
# 19           0.114829                    On Your Own         Vacations
# 20           0.107196                   Fly Out West          Yot Club
# 21           0.115725       i hope she loves me back         boy pablo
#
#     primary  secondary
# 0       3.0        4.0
# 1       1.0        3.0
# 2       4.0        2.0
# 3       1.0        6.0
# 4       1.0        5.0
# 5       5.0        6.0
# 6       5.0        2.0
# 7       3.0        4.0
# 8       NaN        NaN
# 9       4.0        2.0
# 10      3.0        2.0
# 11      3.0        4.0
# 12      3.0        1.0
# 13      2.0        1.0
# 14      2.0        1.0
# 15      3.0        4.0
# 16      2.0        1.0
# 17      3.0        4.0
# 18      4.0        5.0
# 19      2.0        5.0
# 20      2.0        5.0
# 21      2.0        3.0

# %%
# save the basic features, neural network features and the feature names
if not existing_features:
    new_features = new_features[['title', 'artist', 'tempo', 'chroma_number', 
                                 'zero_crossing_rate', 'energy_entropy', 
                                 'spectral_centroid', 'primary', 'secondary']]
    new_features.to_csv("../data/features.csv", header = True, index = False)
    
    nn_features_df.to_csv("../data/nn_features.csv", header = True, index = False)
    
    feat_names_df = pd.DataFrame(feat_names)
    feat_names_df.to_csv("../data/nn_feature_names.csv", header = True, index = False)
else:
    # concatenate the previous features with new features and overwrite the existing files
    previous_features = previous_features.drop(columns = ['song'])
    all_features = pd.concat([previous_features, new_features], ignore_index = True)
    all_features = all_features[['title', 'artist', 'tempo', 'chroma_number', 
                                 'zero_crossing_rate', 'energy_entropy', 
                                 'spectral_centroid', 'primary', 'secondary']]
    all_features.to_csv("../data/features.csv", header = True, index = False)
    
    prev_nn = pd.read_csv("../data/nn_features.csv")
    all_nn = pd.concat([prev_nn, nn_features_df], ignore_index = True)
    all_nn.to_csv("../data/nn_features.csv", header = True, index = False)
